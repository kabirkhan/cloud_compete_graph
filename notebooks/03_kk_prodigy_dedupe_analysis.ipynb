# %%
import os
import pandas as pd
from pathlib import Path
import requests
from dotenv import load_dotenv, find_dotenv

# %%
from src.data.cosmos import GremlinQueryManager, DocumentQueryManager
from src.data.graph.gremlin import GremlinQueryBuilder

# %%
load_dotenv(find_dotenv())

account_name = os.environ.get('COSMOS_ACCOUNT_NAME')
db_name = os.environ.get('COSMOS_DB_NAME')
graph_name = os.environ.get('COSMOS_GRAPH_NAME')
master_key = os.environ.get('COSMOS_MASTER_KEY')
search_key = os.environ.get('AZURE_SEARCH_KEY')
search_account_name = os.environ.get('AZURE_ACCOUNT_NAME')

gremlin_qm = GremlinQueryManager(account_name, master_key, db_name, graph_name)
doc_qm = DocumentQueryManager(account_name, master_key, db_name)

# %%
services_data = []

abbrs = gremlin_qm.query('g.V().has("label", "cloud").values("abbreviation")')
for abbr in abbrs:
# abbr = 'azure'
    q = f"""g.V().has("label", "{abbr}_service")
            .project("id", "name", "shortDescription", "longDescription", "uri", "iconUri", "categories", "relatedServices", "cloud")
            .by("id").by("name").by("short_description").by("long_description").by("uri").by("icon_uri")
            .by(out("belongs_to").values("name").fold())
            .by(coalesce(out("related_service").id().fold(), __.not(identity()).fold()))
            .by(out("belongs_to").out("source_cloud").values("name"))"""
    cloud_data = gremlin_qm.query(q)
    services_data += cloud_data
    
len(services_data)
# Out:
# 822

# %%
[s for s in services_data if s['name'] == 'Azure Kubernetes Service (AKS)']
# Out:
# [{'id': '1663680c-57b4-4de6-a3c4-aa82852e093a',
#   'name': 'Azure Kubernetes Service (AKS)',
#   'shortDescription': 'Simplify the deployment, management, and operations of Kubernetes',
#   'longDescription': 'Azure Kubernetes Service (AKS) manages your hosted Kubernetes environment, making it quick and easy to deploy and manage containerized applications without container orchestration expertise. It also eliminates the burden of ongoing operations and maintenance by provisioning, upgrading, and scaling resources on demand, without taking your applications offline.',
#   'uri': 'https://docs.microsoft.com/en-us/azure/aks/',
#   'iconUri': 'https://docs.microsoft.com/en-us/azure/media/index/containerservice.svg',
#   'categories': ['Compute', 'Containers'],
#   'relatedServices': ['76c946da-b923-49cf-a1e5-24ae089d53c3',
#    'f83feec0-f005-470b-a9a9-67a76f108227'],
#   'cloud': 'Microsoft Azure',
#   '@search.action': 'mergeOrUpload'}]

# %%
class AzureSearchClient:
    def __init__(self, account_name, api_key):
        self.account_name = account_name
        self.api_key = api_key
        self.default_headers = {
            'api-key': api_key
        }
        
    def run_search(search_term):
        search_url = f'https://{self.account_name}.search.windows.net/indexes/services-v0/docs/autocomplete'
        params = {
            'api-version': '2017-11-11-preview',
            'search': search_term,
            '$top': 3,
            'scoringProfile': 'boostName',
            'autocompleteMode': 'twoTerms'
        }
        
        res = requests.get(search_url, headers=self.default_headers, params=params)
        return res
        
    def upsert_index(self, index_name, fields_config, suggesters, scoring_profiles):
        kwargs = {
            'headers': self.default_headers,
            'json': {
                'name': index_name,
                'fields': fields_config,
                'suggesters': suggesters,
                'scoringProfiles': scoring_profiles
            }
        }
        delete_res = requests.delete(f"https://{self.account_name}.search.windows.net/indexes/{index_name}?api-version=2017-11-11", **kwargs)
        res = requests.post(
            f"https://{self.account_name}.search.windows.net/indexes/?api-version=2017-11-11",
            **kwargs
        )
        return res
    
    def upload_data(self, index_name, data):
        for i in range(len(data)):
            data[i]['@search.action'] = 'mergeOrUpload'
        res = requests.post(
            f"https://{self.account_name}.search.windows.net/indexes/{index_name}/docs/index?api-version=2017-11-11",
            headers=self.default_headers,
            json={
                'value': data
            }
        )
        return res
    
    def upsert_synonym_map(self, name, synonyms):
        kwargs = {
            'headers': self.default_headers,
            'json': {
                'name': name,
                'format': 'solr',
                'synonyms': synonyms
            }
        }

        res = requests.post(
            f"https://{self.account_name}.search.windows.net/synonymmaps?api-version=2017-11-11",
            **kwargs
        )
        if res.status_code > 299:
            res = requests.put(
                f"https://{self.account_name}.search.windows.net/synonymmaps/{name}?api-version=2017-11-11",
                **kwargs
            )
            
        return res
        
    
search_client = AzureSearchClient(search_account_name, search_key)

# %%
azure_synonyms = """
AD, Active Directory, AAD\n
AKS, Azure Kubernetes Service\n,
function, functions
database, databases
"""
search_client.upsert_synonym_map('azure-service-abbreviations', azure_synonyms).text
# Out:
# ''

# %%
services_v0_field_config = [
    {"name": "id", "type": "Edm.String", "key": True, "searchable": False, "sortable": False, "facetable": False},
    {"name": "name", "type": "Edm.String", "synonymMaps":["azure-service-abbreviations"]},
    {"name": "shortDescription", "type": "Edm.String", "filterable": False, "sortable": False, "facetable": False},
    {"name": "longDescription", "type": "Edm.String", "filterable": False, "sortable": False, "facetable": False},
    {"name": "uri", "type": "Edm.String", "facetable": False},
    {"name": "iconUri", "type": "Edm.String", "facetable": False},
    {"name": "categories", "type": "Collection(Edm.String)"},
    {"name": "relatedServices", "type": "Collection(Edm.String)", "searchable": False, "filterable": False, "sortable": False, "facetable": False},
    {"name": "cloud", "type": "Edm.String", "searchable": False, "sortable": False}
]

suggesters = [  
    {  
        "name": "suggest-name",  
        "searchMode": "analyzingInfixMatching",  
        "sourceFields": ["name"]
    }  
]

scoring_profiles = [  
    {  
      "name": "boostName",  
      "text": {  
        "weights": {  
          "name": 3          
        }  
      }  
    }
]

r = search_client.upsert_index(
    'services-v0', services_v0_field_config, suggesters, scoring_profiles
)
r
# Out:
# <Response [201]>

# %%
upload_res = search_client.upload_data('services-v0', services_data)
upload_res.status_code
# Out:
# 200

# %%
gremlin_qm.query('g.V("7397ee26-10f0-40a7-9e9f-393a53686e42").in("source_cloud")')
# Out:
# [{'id': '1a629f6c-8ca7-43f2-8eb6-76eecd7fe0cf',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '54f59ebf-5a0a-4824-9841-10de80679f2f',
#      'value': 'Analytics'}]}},
#  {'id': 'fb88345e-f6ea-4508-a191-3c03563b96b0',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '368b14a5-dd14-428c-8dda-c83424ded5e1',
#      'value': 'Application Integration'}]}},
#  {'id': 'bf2f3feb-82e9-411b-92e5-04df21599a39',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '00a1890d-2057-49e0-b110-ad1c5ae7b341',
#      'value': 'AR & VR'}]}},
#  {'id': 'c4a12b19-c1b7-4e48-9c15-5785e363b4bd',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '91d95bfd-29af-4713-a9ff-03322ae12094',
#      'value': 'AWS Cost Management'}]}},
#  {'id': 'f6a2df1a-a3a6-427e-848d-ff325c49957f',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '55974085-532c-4ce8-96dc-5c7cb7fce324',
#      'value': 'Blockchain'}]}},
#  {'id': '7cbeeab2-1ad3-4e98-a0fa-56dcd37b219c',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'd8623492-ea5b-4528-925e-1308f3762aa7',
#      'value': 'Business Applications'}]}},
#  {'id': '1e782738-935b-4bf7-b35f-36a11e31f215',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '7a183188-065e-4420-b7c4-8576ae7d2238',
#      'value': 'Compute'}]}},
#  {'id': 'cbddc303-302b-4c6c-b565-afc60ca46ba0',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '9a3c36b2-c1bc-43b8-ac2d-b2eda8e65932',
#      'value': 'Customer Engagement'}]}},
#  {'id': '6963d9c0-3670-443f-a639-7fdb840466d6',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'b490bd4e-0797-410a-824b-9a29dbcf6fd3',
#      'value': 'Database'}]}},
#  {'id': '0123d6f1-e92c-46f5-944c-030dda796d6d',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '3b724c14-ed3b-4bcd-a760-5ac6686f6634',
#      'value': 'Developer Tools'}]}},
#  {'id': '12e57bde-703e-4dfc-ba12-d5d4262039a6',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '46345cee-1a74-498f-8020-8c9d3f4aaff0',
#      'value': 'End User Computing'}]}},
#  {'id': 'b586b167-f828-4455-a9e7-6477d0b5527e',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '63332431-da27-440d-bf0a-9eaa84a9ffd3',
#      'value': 'Game Tech'}]}},
#  {'id': 'f1261502-4ad1-455f-b667-13e027ffefc4',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '6ff823d6-467f-49d4-a785-c61794973a2e',
#      'value': 'Internet of Things'}]}},
#  {'id': '08f7173a-52d0-46ed-8961-da344b1cdb78',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'a2550921-2a90-412e-ba11-4a3f5e940e57',
#      'value': 'Machine Learning'}]}},
#  {'id': '8fbdf77e-42cf-44e0-986d-4dc20c6c14b2',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'e5c271c8-94d8-4760-92f2-c33df4138e16',
#      'value': 'Management & Governance'}]}},
#  {'id': '988cc64b-eac3-498e-aa71-ee73c8e994c2',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'a88ae746-ecce-43de-b00a-8dd4587461f7',
#      'value': 'Media Services'}]}},
#  {'id': '32972297-6ed4-4019-9b66-ae99f6294a11',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '9f989c4b-5275-4870-a5ba-cf7eea19aa1d',
#      'value': 'Migration & Transfer'}]}},
#  {'id': 'b30a9071-1b2a-4b98-9bda-7d1275c548e7',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'c3dffdba-3a40-4531-9cb0-fffe77e8aa65',
#      'value': 'Mobile'}]}},
#  {'id': '48f7cb12-2b35-46e9-9926-7a081927c743',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '7cf4b440-2ec8-4d01-8a2c-f4ea070f44f4',
#      'value': 'Networking & Content Delivery'}]}},
#  {'id': 'e200cb65-d0e0-4ace-a2b8-293785783341',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '1ae8e646-7b7f-4ce0-aae9-efee9c8e2ee9',
#      'value': 'Robotics'}]}},
#  {'id': '35d01fd2-e933-48c6-9cf4-013d1931daa3',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'd1f3cf17-2ac9-46c2-8d68-a57d12b1e991',
#      'value': 'Satellite'}]}},
#  {'id': '7af96f8a-9f00-40da-b088-d8ee7f3dd8f7',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '1df59a2f-c71c-4a8e-8485-9d874c79f864',
#      'value': 'Security, Identity & Compliance'}]}},
#  {'id': '02c19c24-98da-459f-ac0b-d6646aa04394',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '7f73619f-28bd-45ca-9c58-de015702b456',
#      'value': 'Storage'}]}}]

# %%
aws_azure_df = pd.read_csv('../data/processed/aws_azure_data_matching_output.csv')
aws_azure_related = aws_azure_df[aws_azure_df['Link Score'] > 0.6].sort_values(['Cluster ID'])

def get_svc_id(gremlin_qm, svc_name):
    q = f'g.V().has("name", "{svc_name}").values("id")'
    res = gremlin_qm.query(q)
    return res[0]

def build_related_query(from_id, to_id):
    return GremlinQueryBuilder.build_upsert_edge_query(from_id, to_id, {
        'label': 'related_service', 'related_service_score': aws_svc['Link Score']
    })

for i in range(list(aws_azure_related['Cluster ID'])[-1] + 1):
    related_services = aws_azure_related[aws_azure_related['Cluster ID'] == i].reset_index(drop=True)
    aws_svc = related_services.iloc[0]
    azure_svc = related_services.iloc[1]
    
    aws_id = get_svc_id(gremlin_qm, aws_svc['name'])
    azure_id = get_svc_id(gremlin_qm, azure_svc['name'])
    
    print(f'Adding related_service edges between {aws_svc["name"]} and {azure_svc["name"]}')
# Out:
# Adding related_service edges between Amazon Elastic Container Service and Azure Container Instances
# Adding related_service edges between AWS Batch and Azure Batch
# Adding related_service edges between Azure Kubernetes Service (AKS) and Amazon Elastic Container Service for Kubernetes
# Adding related_service edges between Amazon Cloud Directory and Azure Active Directory
# Adding related_service edges between Amazon API Gateway and Azure Application Gateway
# Adding related_service edges between Azure Database Migration Service and AWS Database Migration Service
# Adding related_service edges between Azure IoT Central and AWS IoT Analytics
# Adding related_service edges between AWS Key Management Service and Azure Key Vault
# Adding related_service edges between Amazon Aurora and Azure SQL Database
# Adding related_service edges between Azure IoT Hub Device Provisioning Service and AWS IoT Device Management
# Adding related_service edges between AWS IoT Core and Azure IoT Hub
# Adding related_service edges between Azure SDKs and AWS Tools and SDKs
# Adding related_service edges between AWS Lambda and Azure Functions
# Adding related_service edges between Azure File Storage and Amazon FSx for Windows File Server
# Adding related_service edges between Amazon CloudFront and Azure Content Delivery Network
# Adding related_service edges between Amazon Simple Storage Service (S3) and Azure Storage
# Adding related_service edges between Azure ExpressRoute and AWS Direct Connect
# Adding related_service edges between AWS Lake Formation and Azure Data Lake Analytics
# Adding related_service edges between Azure Data Box family and AWS Snow Family
# Adding related_service edges between Azure Machine Learning Services and Amazon SageMaker
# Adding related_service edges between AWS IoT Things Graph and Azure IoT Fundamentals
# Adding related_service edges between Azure Log Analytics and Amazon CloudSearch
# Adding related_service edges between Azure StorSimple and AWS Storage Gateway
# Adding related_service edges between AWS Directory Service and Azure Active Directory B2C
# Adding related_service edges between Azure Database for MySQL and Amazon RDS
# Adding related_service edges between AWS Elastic Beanstalk and Azure App Service
# Adding related_service edges between Amazon DynamoDB and Azure Table Storage
# Adding related_service edges between AWS Global Accelerator and Azure Traffic Manager
# Adding related_service edges between AWS Identity & Access Management and Azure Role-based access control

# %%
aws_azure_related.head()
# Out:
#      Cluster ID  Link Score  source file category_name  \
# 28            0    0.996641            0       Compute
# 181           0    0.996641            1       Compute
# 32            1    0.993355            0       Compute
# 180           1    0.993355            1       Compute
# 184           2    0.990656            1       Compute
#
#                                  name  \
# 28   Amazon Elastic Container Service
# 181         Azure Container Instances
# 32                          AWS Batch
# 180                       Azure Batch
# 184    Azure Kubernetes Service (AKS)
#
#                                      short_description  \
# 28                    Run and Manage Docker Containers
# 181        Easily run containers with a single command
# 32                         Run Batch Jobs at Any Scale
# 180  Cloud-scale job scheduling and compute management
# 184  Simplify the deployment, management, and opera...
#
#                                       long_description
# 28   Amazon Elastic Container Service (Amazon ECS) ...
# 181  Azure Container Instances offers the fastest a...
# 32   AWS Batch enables developers, scientists, and ...
# 180  Use Batch to run large-scale parallel and high...
# 184  Azure Kubernetes Service (AKS) manages your ho...

# %%
azure_gcp_df = pd.read_csv('../data/processed/azure_gcp_data_matching_output.csv')
azure_gcp_related = azure_gcp_df[azure_gcp_df['Link Score'] > 0.6].sort_values(['Cluster ID'])

def get_svc_id(gremlin_qm, svc_name):
    q = f'g.V().has("name", "{svc_name}").values("id")'
    return gremlin_qm.query(q)[0]

def build_related_query(from_id, to_id, score):
    return GremlinQueryBuilder.build_upsert_edge_query(from_id, to_id, {
        'label': 'related_service', 'related_service_score': score
    })

azure_gcp_related
# Out:
#      Cluster ID  Link Score  source file                    category_name  \
# 3             0    0.999976            0                          Compute
# 179           0    0.999976            1                          Compute
# 248           1    0.999780            1    Networking & Content Delivery
# 16            1    0.999780            0    Networking & Content Delivery
# 79            2    0.998992            0            AI + Machine Learning
# 157           2    0.998992            1            AI + Machine Learning
# 130           3    0.998803            0                 Management Tools
# 231           3    0.998803            1                 Management tools
# 229           4    0.998419            1                 Management tools
# 126           4    0.998419            0                 Management Tools
# 257           5    0.996383            1  Security, Identity & Compliance
# 104           5    0.996383            0  Security, Identity & Compliance
# 259           6    0.993404            1  Security, Identity & Compliance
# 103           6    0.993404            0  Security, Identity & Compliance
# 102           7    0.992686            0  Security, Identity & Compliance
# 261           7    0.992686            1  Security, Identity & Compliance
# 112           8    0.988107            0                  Developer Tools
# 209           8    0.988107            1                  Developer Tools
# 147           9    0.987812            1                          Compute
# 2             9    0.987812            0                          Compute
# 186          10    0.981809            1                        Analytics
# 65           10    0.981809            0                        Analytics
# 244          11    0.972269            1    Networking & Content Delivery
# 14           11    0.972269            0    Networking & Content Delivery
# 125          12    0.970342            0                 Management Tools
# 227          12    0.970342            1                 Management tools
# 20           13    0.966969            0    Networking & Content Delivery
# 247          13    0.966969            1    Networking & Content Delivery
# 5            14    0.933990            0                          Compute
# 183          14    0.933990            1                          Compute
# 249          15    0.918926            1    Networking & Content Delivery
# 23           15    0.918926            0    Networking & Content Delivery
# 151          16    0.908747            1                          Compute
# 10           16    0.908747            0                          Compute
# 53           17    0.900171            0                        Databases
# 196          17    0.900171            1                        Databases
# 265          18    0.843290            1                          Storage
# 32           18    0.843290            0                          Storage
# 267          19    0.768300            1                          Storage
# 35           19    0.768300            0                          Storage
# 252          20    0.729586            1  Security, Identity & Compliance
# 100          20    0.729586            0  Security, Identity & Compliance
# 177          21    0.708344            1                          Compute
# 8            21    0.708344            0                          Compute
# 185          22    0.699019            1                        Analytics
# 67           22    0.699019            0                        Analytics
# 251          23    0.695267            1  Security, Identity & Compliance
# 106          23    0.695267            0  Security, Identity & Compliance
# 17           24    0.694657            0    Networking & Content Delivery
# 250          24    0.694657            1    Networking & Content Delivery
# 19           25    0.677578            0    Networking & Content Delivery
# 242          25    0.677578            1    Networking & Content Delivery
# 155          26    0.608688            1            AI + Machine Learning
# 80           26    0.608688            0            AI + Machine Learning
#
#                                                  name  \
# 3                                     Azure Functions
# 179                                   Cloud Functions
# 248                                         Cloud DNS
# 16                                          Azure DNS
# 79                    Azure Machine Learning Services
# 157                     Cloud Machine Learning Engine
# 130                             Azure Cost Management
# 231                                   Cost management
# 229                                       Cloud Shell
# 126                                 Azure Cloud Shell
# 257                                         Cloud HSM
# 104                               Azure Dedicated HSM
# 259                      Cloud Key Management Service
# 103                                   Azure Key Vault
# 102                             Azure Security Center
# 261              Cloud Security Command Center (beta)
# 112                               Azure Visual Studio
# 209                     Cloud Tools for Visual Studio
# 147                                        App Engine
# 2                                   Azure App Service
# 186                                    Cloud Dataproc
# 65                                    Azure HDInsight
# 244                                         Cloud CDN
# 14                     Azure Content Delivery Network
# 125                            Azure Resource Manager
# 227                          Cloud Deployment Manager
# 20                                  Azure VPN Gateway
# 247                                         Cloud VPN
# 5                           Azure Container Instances
# 183                                Container security
# 249                             Network Service Tiers
# 23                              Azure Network Watcher
# 151                                         Cloud SQL
# 10               Azure SQL Server on Virtual Machines
# 53                                 Azure SQL Database
# 196                                     Cloud Spanner
# 265                                   Persistent Disk
# 32                                 Azure Disk Storage
# 267                                   Cloud Filestore
# 35                                 Azure File Storage
# 252  Cloud Identity for Customers and Partners (beta)
# 100                        Azure Active Directory B2C
# 177                          Google Kubernetes Engine
# 8                      Azure Kubernetes Service (AKS)
# 185                                    Cloud Dataflow
# 67                             Azure Stream Analytics
# 251                                         Cloud IAM
# 106                   Azure Role-based access control
# 17                              Azure Virtual Network
# 250                                 Network Telemetry
# 19                                Azure Load Balancer
# 242                              Cloud Load Balancing
# 155                               Cloud AutoML (beta)
# 80                      Azure Machine Learning Studio
#
#                                      short_description  \
# 3                  Process events with serverless code
# 179          Event-driven serverless compute platform.
# 248      Reliable, resilient, low-latency DNS serving.
# 16                       Host your DNS domain in Azure
# 79   Build, deploy, and manage machine learning and...
# 157  Build superior models and deploy them into pro...
# 130  Optimize what you spend on the cloud, while ma...
# 231  Tools for monitoring, controlling, and optimiz...
# 229          Command-line management from any browser.
# 126  Streamline Azure administration with a browser...
# 257  Protect cryptographic keys with a fully manage...
# 104             Use cryptographic key storage in Azure
# 259                     Manage encryption keys on GCP.
# 103  Safeguard and maintain control of keys and oth...
# 102  Unify security management and enable advanced ...
# 261  Comprehensive security and data risk platform ...
# 112  Fully-featured integrated development environm...
# 209          Deploy Visual Studio applications to GCP.
# 147  Serverless application platform for apps and b...
# 2    Quickly create powerful cloud apps for web and...
# 186                  Managed Spark and Hadoop service.
# 65   Provision cloud Hadoop, Spark, R Server, HBase...
# 244       Content delivery on Google's global network.
# 14   Ensure secure, reliable content delivery with ...
# 125         Simplify how you manage your app resources
# 227      Manage cloud resources with simple templates.
# 20       Establish secure, cross-premises connectivity
# 247  Securely connect to your GCP VPC via the publi...
# 5          Easily run containers with a single command
# 183          Secure your container environment on GCP.
# 249     Optimize your network for performance or cost.
# 23   Network performance monitoring and diagnostics...
# 151             MySQL and PostgreSQL database service.
# 10        Host enterprise SQL Server apps in the cloud
# 53        Managed relational SQL Database as a service
# 196  Mission-critical, scalable, relational databas...
# 265                    Block storage for VM instances.
# 32   Persistent, secured disk options supporting vi...
# 267                     High-performance file storage.
# 35   File shares that use the standard SMB 3.0 prot...
# 252  Add Google-grade identity and access managemen...
# 100  Consumer identity and access management in the...
# 177                    Run containerized applications.
# 8    Simplify the deployment, management, and opera...
# 185        Real-time batch and stream data processing.
# 67   Real-time data stream processing from millions...
# 251       Fine-grained identity and access management.
# 106                   Manage access to Azure resources
# 17   Provision private networks, optionally connect...
# 250  In-depth network telemetry to keep your servic...
# 19   Deliver high availability and network performa...
# 242         High-performance, scalable load balancing.
# 155       Easily train high-quality, custom ML models.
# 80   Easily build, deploy, and manage predictive an...
#
#                                       long_description
# 3    Azure Functions is a serverless compute servic...
# 179  Google Cloud Functions makes it easy for devel...
# 248  Reliable, low-latency, authoritative DNS servi...
# 16   Learn how to use Azure DNS. Quickstarts, tutor...
# 79   Learn how to build intelligent algorithms into...
# 157  Create your predictive analytics and machine l...
# 130  Azure Cost Management is a cost management sol...
# 231  Increase cost predictability. Gain greater vis...
# 229  Google Cloud Shell is a free admin machine wit...
# 126  Azure Cloud Shell is an interactive, browser-a...
# 257  Cloud HSM is a fully-managed service that allo...
# 104  Learn about Dedicated HSM functionality and wh...
# 259  Cloud KMS securely manages encryption keys and...
# 103  Learn how to use Key Vault to safeguard and ma...
# 102  Azure Security Center provides unified securit...
# 261  Cloud Security Command Center helps security t...
# 112  Build apps and games, using Windows, to reach ...
# 209  Cloud Tools for Visual Studio is a powerful en...
# 147  Google App Engine lets developers build scalab...
# 2    Azure App Service enables you to build and hos...
# 186  Managed Apache Spark and Apache Hadoop service...
# 65   Learn how to use Azure HDInsight to analyze st...
# 244  Google Cloud CDN provides low-latency content ...
# 14   Azure Content Delivery Network (CDN) is a glob...
# 125  Learn how to use Resource Manager to deploy, m...
# 227  From simple web servers to complex highly avai...
# 20   Learn how to configure, create, and manage an ...
# 247  Connect to Google Cloud Platform via enterpris...
# 5    Azure Container Instances offers the fastest a...
# 183  Discover how to secure your Kubernetes Engine ...
# 249  Network Service Tiers is the first customizabl...
# 23   Learn how to use Azure Network Watcher. Quicks...
# 151  Google Cloud SQL is a fully-managed relational...
# 10   SQL Server on Azure virtual machines enables y...
# 53   Azure SQL Database is a relational database-as...
# 196  The only enterprise-grade, globally-distribute...
# 265  Persistent Disk is Google’s local durable stor...
# 32   Just like any other computer, virtual machines...
# 267                   Fully-managed cloud file storage
# 35   Azure Files offers fully managed file shares i...
# 252  Add identity and access management functionali...
# 100  Azure Active Directory (Azure AD) B2C is an id...
# 177  Google Kubernetes Engine is a powerful cluster...
# 8    Azure Kubernetes Service (AKS) manages your ho...
# 185  Simplified stream and batch data processing, w...
# 67   Learn how to run Internet of Things (IoT) anal...
# 251  Google Cloud Identity & Access Management (IAM...
# 106  Role-based access control (RBAC) is a system t...
# 17   Learn how to use Azure Virtual Network. Quicks...
# 250  Identify traffic and access patterns that may ...
# 19   Learn how to use Azure Load Balancer. Quicksta...
# 242  High performance, scalable global load balanci...
# 155  Cloud AutoML helps you easily train high quali...
# 80   Azure Machine Learning Studio is a collaborati...

# %%
def update_related_services(prodigy_data_matching_output_df):
    for i in range(list(prodigy_data_matching_output_df['Cluster ID'])[-1] + 1):
        
        related_services = prodigy_data_matching_output_df[prodigy_data_matching_output_df['Cluster ID'] == i].reset_index(drop=True)
        left_svc = related_services[related_services['source file'] == 0].iloc[0]
        right_svc = related_services[related_services['source file'] == 1].iloc[0]
        
        left_id = get_svc_id(gremlin_qm, left_svc['name'])
        right_id = get_svc_id(gremlin_qm, right_svc['name'])

        
        left_related_edges = gremlin_qm.query(f"g.V('{left_id}').outE('related_service')")
        for rel_svc in left_related_edges:
            if rel_svc['inV'] != right_id:
                score = rel_svc['properties']['related_service_score']

                gremlin_qm.query(build_related_query(rel_svc['inV'], right_id, score))
                gremlin_qm.query(build_related_query(right_id, rel_svc['inV'], score))
        
        print(f'Adding related_service edges between {left_svc["name"]} and {right_svc["name"]}')
        gremlin_qm.query(build_related_query(left_id, right_id, left_svc['Link Score']))
        gremlin_qm.query(build_related_query(right_id, left_id, left_svc['Link Score']))

update_related_services(azure_gcp_related)
# Out:
# Adding related_service edges between Azure Functions and Cloud Functions
# Adding related_service edges between Azure DNS and Cloud DNS
# Adding related_service edges between Azure Machine Learning Services and Cloud Machine Learning Engine
# Adding related_service edges between Azure Cost Management and Cost management
# Adding related_service edges between Azure Cloud Shell and Cloud Shell
# Adding related_service edges between Azure Dedicated HSM and Cloud HSM
# Adding related_service edges between Azure Key Vault and Cloud Key Management Service
# Adding related_service edges between Azure Security Center and Cloud Security Command Center (beta)
# Adding related_service edges between Azure Visual Studio and Cloud Tools for Visual Studio
# Adding related_service edges between Azure App Service and App Engine
# Adding related_service edges between Azure HDInsight and Cloud Dataproc
# Adding related_service edges between Azure Content Delivery Network and Cloud CDN
# Adding related_service edges between Azure Resource Manager and Cloud Deployment Manager
# Adding related_service edges between Azure VPN Gateway and Cloud VPN
# Adding related_service edges between Azure Container Instances and Container security
# Adding related_service edges between Azure Network Watcher and Network Service Tiers
# Adding related_service edges between Azure SQL Server on Virtual Machines and Cloud SQL
# Adding related_service edges between Azure SQL Database and Cloud Spanner
# Adding related_service edges between Azure Disk Storage and Persistent Disk
# Adding related_service edges between Azure File Storage and Cloud Filestore
# Adding related_service edges between Azure Active Directory B2C and Cloud Identity for Customers and Partners (beta)
# Adding related_service edges between Azure Kubernetes Service (AKS) and Google Kubernetes Engine
# Adding related_service edges between Azure Stream Analytics and Cloud Dataflow
# Adding related_service edges between Azure Role-based access control and Cloud IAM
# Adding related_service edges between Azure Virtual Network and Network Telemetry
# Adding related_service edges between Azure Load Balancer and Cloud Load Balancing
# Adding related_service edges between Azure Machine Learning Studio and Cloud AutoML (beta)
