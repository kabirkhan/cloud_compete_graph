# %%
import os
import pandas as pd
from pathlib import Path
import requests
from dotenv import load_dotenv, find_dotenv

# %%
from src.data.cosmos import GremlinQueryManager
from src.data.graph.gremlin import GremlinQueryBuilder

# %%
load_dotenv(find_dotenv())

account_name = os.environ.get('COSMOS_ACCOUNT_NAME')
db_name = os.environ.get('COSMOS_DB_NAME')
graph_name = os.environ.get('COSMOS_GRAPH_NAME')
master_key = os.environ.get('COSMOS_MASTER_KEY')

gremlin_qm = GremlinQueryManager(account_name, master_key, db_name, graph_name)

# %%
gremlin_qm.query('g.V("7397ee26-10f0-40a7-9e9f-393a53686e42").in("source_cloud")')
# Out:
# [{'id': '1a629f6c-8ca7-43f2-8eb6-76eecd7fe0cf',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '54f59ebf-5a0a-4824-9841-10de80679f2f',
#      'value': 'Analytics'}]}},
#  {'id': 'fb88345e-f6ea-4508-a191-3c03563b96b0',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '368b14a5-dd14-428c-8dda-c83424ded5e1',
#      'value': 'Application Integration'}]}},
#  {'id': 'bf2f3feb-82e9-411b-92e5-04df21599a39',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '00a1890d-2057-49e0-b110-ad1c5ae7b341',
#      'value': 'AR & VR'}]}},
#  {'id': 'c4a12b19-c1b7-4e48-9c15-5785e363b4bd',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '91d95bfd-29af-4713-a9ff-03322ae12094',
#      'value': 'AWS Cost Management'}]}},
#  {'id': 'f6a2df1a-a3a6-427e-848d-ff325c49957f',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '55974085-532c-4ce8-96dc-5c7cb7fce324',
#      'value': 'Blockchain'}]}},
#  {'id': '7cbeeab2-1ad3-4e98-a0fa-56dcd37b219c',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'd8623492-ea5b-4528-925e-1308f3762aa7',
#      'value': 'Business Applications'}]}},
#  {'id': '1e782738-935b-4bf7-b35f-36a11e31f215',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '7a183188-065e-4420-b7c4-8576ae7d2238',
#      'value': 'Compute'}]}},
#  {'id': 'cbddc303-302b-4c6c-b565-afc60ca46ba0',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '9a3c36b2-c1bc-43b8-ac2d-b2eda8e65932',
#      'value': 'Customer Engagement'}]}},
#  {'id': '6963d9c0-3670-443f-a639-7fdb840466d6',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'b490bd4e-0797-410a-824b-9a29dbcf6fd3',
#      'value': 'Database'}]}},
#  {'id': '0123d6f1-e92c-46f5-944c-030dda796d6d',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '3b724c14-ed3b-4bcd-a760-5ac6686f6634',
#      'value': 'Developer Tools'}]}},
#  {'id': '12e57bde-703e-4dfc-ba12-d5d4262039a6',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '46345cee-1a74-498f-8020-8c9d3f4aaff0',
#      'value': 'End User Computing'}]}},
#  {'id': 'b586b167-f828-4455-a9e7-6477d0b5527e',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '63332431-da27-440d-bf0a-9eaa84a9ffd3',
#      'value': 'Game Tech'}]}},
#  {'id': 'f1261502-4ad1-455f-b667-13e027ffefc4',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '6ff823d6-467f-49d4-a785-c61794973a2e',
#      'value': 'Internet of Things'}]}},
#  {'id': '08f7173a-52d0-46ed-8961-da344b1cdb78',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'a2550921-2a90-412e-ba11-4a3f5e940e57',
#      'value': 'Machine Learning'}]}},
#  {'id': '8fbdf77e-42cf-44e0-986d-4dc20c6c14b2',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'e5c271c8-94d8-4760-92f2-c33df4138e16',
#      'value': 'Management & Governance'}]}},
#  {'id': '988cc64b-eac3-498e-aa71-ee73c8e994c2',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'a88ae746-ecce-43de-b00a-8dd4587461f7',
#      'value': 'Media Services'}]}},
#  {'id': '32972297-6ed4-4019-9b66-ae99f6294a11',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '9f989c4b-5275-4870-a5ba-cf7eea19aa1d',
#      'value': 'Migration & Transfer'}]}},
#  {'id': 'b30a9071-1b2a-4b98-9bda-7d1275c548e7',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'c3dffdba-3a40-4531-9cb0-fffe77e8aa65',
#      'value': 'Mobile'}]}},
#  {'id': '48f7cb12-2b35-46e9-9926-7a081927c743',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '7cf4b440-2ec8-4d01-8a2c-f4ea070f44f4',
#      'value': 'Networking & Content Delivery'}]}},
#  {'id': 'e200cb65-d0e0-4ace-a2b8-293785783341',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '1ae8e646-7b7f-4ce0-aae9-efee9c8e2ee9',
#      'value': 'Robotics'}]}},
#  {'id': '35d01fd2-e933-48c6-9cf4-013d1931daa3',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': 'd1f3cf17-2ac9-46c2-8d68-a57d12b1e991',
#      'value': 'Satellite'}]}},
#  {'id': '7af96f8a-9f00-40da-b088-d8ee7f3dd8f7',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '1df59a2f-c71c-4a8e-8485-9d874c79f864',
#      'value': 'Security, Identity & Compliance'}]}},
#  {'id': '02c19c24-98da-459f-ac0b-d6646aa04394',
#   'label': 'aws_category',
#   'type': 'vertex',
#   'properties': {'name': [{'id': '7f73619f-28bd-45ca-9c58-de015702b456',
#      'value': 'Storage'}]}}]

# %%
aws_azure_df = pd.read_csv('../data/processed/aws_azure_data_matching_output.csv')
aws_azure_related = aws_azure_df[aws_azure_df['Link Score'] > 0.6].sort_values(['Cluster ID'])

def get_svc_id(gremlin_qm, svc_name):
    q = f'g.V().has("name", "{svc_name}").values("id")'
    return gremlin_qm.query(q)[0]

def build_related_query(from_id, to_id):
    return GremlinQueryBuilder.build_upsert_edge_query(from_id, to_id, {
        'label': 'related_service', 'related_service_score': aws_svc['Link Score']
    })

for i in range(list(aws_azure_related['Cluster ID'])[-1] + 1):
    related_services = aws_azure_related[aws_azure_related['Cluster ID'] == i].reset_index(drop=True)
    aws_svc = related_services.iloc[0]
    azure_svc = related_services.iloc[1]
    
    aws_id = get_svc_id(gremlin_qm, aws_svc['name'])
    azure_id = get_svc_id(gremlin_qm, azure_svc['name'])
    
    print(f'Adding related_service edges between {aws_svc["name"]} and {azure_svc["name"]}')
# Out:
# Adding related_service edges between Amazon Elastic Container Service and Azure Container Instances
# [{'id': '3e76213f-a5f6-4b5c-9d78-2bd64b582f81', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '3ca3ca43-8f6d-4b6d-85f9-d08415beed2f', 'outV': '9bcaffb7-743b-4c91-aef6-514da1edfff1', 'properties': {'related_service_score': 0.9966404999999999}}]
# [{'id': '662144a0-e1c9-4ebd-99d2-64b5ca13ed5d', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '9bcaffb7-743b-4c91-aef6-514da1edfff1', 'outV': '3ca3ca43-8f6d-4b6d-85f9-d08415beed2f', 'properties': {'related_service_score': 0.9966404999999999}}]
# Adding related_service edges between AWS Batch and Azure Batch
# [{'id': '4e42a288-987e-4daf-bf79-b813ae2f055b', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'f7bee802-9bce-4612-b85a-3ec54e5462c3', 'outV': 'ffd93a3f-6d9f-46f8-b9a9-11d8c706f92c', 'properties': {'related_service_score': 0.99335533}}]
# [{'id': '27c4a9c5-298f-4bbe-a3fa-14a313b36c42', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'ffd93a3f-6d9f-46f8-b9a9-11d8c706f92c', 'outV': 'f7bee802-9bce-4612-b85a-3ec54e5462c3', 'properties': {'related_service_score': 0.99335533}}]
# Adding related_service edges between Azure Kubernetes Service (AKS) and Amazon Elastic Container Service for Kubernetes
# [{'id': 'e173baf5-c97d-4b7e-a624-3679d2bff5de', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '76c946da-b923-49cf-a1e5-24ae089d53c3', 'outV': '1663680c-57b4-4de6-a3c4-aa82852e093a', 'properties': {'related_service_score': 0.9906562600000001}}]
# [{'id': '7782e236-4173-439d-adeb-5904db544da7', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '1663680c-57b4-4de6-a3c4-aa82852e093a', 'outV': '76c946da-b923-49cf-a1e5-24ae089d53c3', 'properties': {'related_service_score': 0.9906562600000001}}]
# Adding related_service edges between Amazon Cloud Directory and Azure Active Directory
# [{'id': '0bb32924-aa41-455d-a39d-b18c9e63ccf7', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'ca206c65-1ea9-4a8a-84b1-1d1384e759c3', 'outV': 'bfd418ee-0ece-4359-947d-48835ef02b65', 'properties': {'related_service_score': 0.9717998999999999}}]
# [{'id': '5c2d61e9-fbe1-4990-9d33-8437c3fabe6e', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'bfd418ee-0ece-4359-947d-48835ef02b65', 'outV': 'ca206c65-1ea9-4a8a-84b1-1d1384e759c3', 'properties': {'related_service_score': 0.9717998999999999}}]
# Adding related_service edges between Amazon API Gateway and Azure Application Gateway
# [{'id': '07f291c1-312f-4f31-9bb8-6455ca1a57f4', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '85d3148d-464e-4fa2-9634-23c43668d523', 'outV': 'b6e62a37-0a8e-49ae-aa5e-8024c4645a48', 'properties': {'related_service_score': 0.97076577}}]
# [{'id': 'e5859c9f-2321-4560-905f-995bf549be0e', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'b6e62a37-0a8e-49ae-aa5e-8024c4645a48', 'outV': '85d3148d-464e-4fa2-9634-23c43668d523', 'properties': {'related_service_score': 0.97076577}}]
# Adding related_service edges between Azure Database Migration Service and AWS Database Migration Service
# [{'id': 'fb0b84a3-6200-4602-ac6f-da14c575cdf3', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '56c98465-ba5b-46e9-8a28-49b281f1ac95', 'outV': '346e68b8-0617-4793-b68b-ce17d71ad1b7', 'properties': {'related_service_score': 0.9604248}}]
# [{'id': '16a60952-13b7-459c-94f7-6b61806c4d0f', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '346e68b8-0617-4793-b68b-ce17d71ad1b7', 'outV': '56c98465-ba5b-46e9-8a28-49b281f1ac95', 'properties': {'related_service_score': 0.9604248}}]
# Adding related_service edges between Azure IoT Central and AWS IoT Analytics
# [{'id': 'b82e0d74-37e4-4205-9f91-d050acde2a4f', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'fcb61d93-d197-4626-887b-0a43d5a71b08', 'outV': 'e3c57403-0182-4667-abf4-260f1ec1f122', 'properties': {'related_service_score': 0.95662594}}]
# [{'id': '25333eee-c370-477b-a898-6a34a14a659b', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'e3c57403-0182-4667-abf4-260f1ec1f122', 'outV': 'fcb61d93-d197-4626-887b-0a43d5a71b08', 'properties': {'related_service_score': 0.95662594}}]
# Adding related_service edges between AWS Key Management Service and Azure Key Vault
# [{'id': '7d818905-ec78-4eb7-a7a0-889942e1a3e3', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '79a85c4c-a49d-4dee-b37e-99cc399120f7', 'outV': '29c0b315-56dd-4403-856a-fab996a3e665', 'properties': {'related_service_score': 0.95527136}}]
# [{'id': '805bb5db-3b60-4cda-9e84-b81c2204204c', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '29c0b315-56dd-4403-856a-fab996a3e665', 'outV': '79a85c4c-a49d-4dee-b37e-99cc399120f7', 'properties': {'related_service_score': 0.95527136}}]
# Adding related_service edges between Amazon Aurora and Azure SQL Database
# [{'id': 'd470fd57-e2b9-4de0-977c-b30989939131', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '17dbf5b0-dd64-4623-adc9-2aeb7a133db5', 'outV': 'e3942b74-ecea-47ac-a313-02f106b9b946', 'properties': {'related_service_score': 0.9483982999999999}}]
# [{'id': '23ae9739-a818-48ab-9753-d8a2ae933878', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'e3942b74-ecea-47ac-a313-02f106b9b946', 'outV': '17dbf5b0-dd64-4623-adc9-2aeb7a133db5', 'properties': {'related_service_score': 0.9483982999999999}}]
# Adding related_service edges between Azure IoT Hub Device Provisioning Service and AWS IoT Device Management
# [{'id': '1c74430b-7313-4c22-b65c-812321e6e740', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'e40e740f-1a31-4e64-8111-249c349b16cf', 'outV': '0aa80448-ff53-43e9-9c0b-5637ad34e2d5', 'properties': {'related_service_score': 0.9254517600000001}}]
# [{'id': 'ab401df5-668e-4bfd-9bed-771cb576665f', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '0aa80448-ff53-43e9-9c0b-5637ad34e2d5', 'outV': 'e40e740f-1a31-4e64-8111-249c349b16cf', 'properties': {'related_service_score': 0.9254517600000001}}]
# Adding related_service edges between AWS IoT Core and Azure IoT Hub
# [{'id': '59b2436d-c7a1-41fd-ab6d-c5910f5a0236', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '07f90edd-9180-4761-9574-c2fee9624298', 'outV': '65cc24b0-d6ba-4eef-979d-b8331a84f2cb', 'properties': {'related_service_score': 0.88842034}}]
# [{'id': 'fe81c35d-c26b-4915-8c2f-27cc0048ac32', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '65cc24b0-d6ba-4eef-979d-b8331a84f2cb', 'outV': '07f90edd-9180-4761-9574-c2fee9624298', 'properties': {'related_service_score': 0.88842034}}]
# Adding related_service edges between Azure SDKs and AWS Tools and SDKs
# [{'id': '453b1e75-f41c-4cdb-9403-d245dbf1d189', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '72ec56ad-45a9-481b-a913-1b3993e1355b', 'outV': '403a44e9-1ba4-4e3a-b0c1-68b3f1bdc2e3', 'properties': {'related_service_score': 0.8868022600000001}}]
# [{'id': '76e25dc8-dd8e-45a8-bac1-189785926751', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '403a44e9-1ba4-4e3a-b0c1-68b3f1bdc2e3', 'outV': '72ec56ad-45a9-481b-a913-1b3993e1355b', 'properties': {'related_service_score': 0.8868022600000001}}]
# Adding related_service edges between AWS Lambda and Azure Functions
# [{'id': '8212ba27-8f39-4361-a9f9-c8e469f122dc', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'a8450c27-4ed7-45a3-8e08-55ef67910fc3', 'outV': 'ad77902d-10f7-4d3e-971c-8b734a059076', 'properties': {'related_service_score': 0.8862859000000001}}]
# [{'id': '98774ed6-3b9e-499e-a8ee-23addb72b98d', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'ad77902d-10f7-4d3e-971c-8b734a059076', 'outV': 'a8450c27-4ed7-45a3-8e08-55ef67910fc3', 'properties': {'related_service_score': 0.8862859000000001}}]
# Adding related_service edges between Azure File Storage and Amazon FSx for Windows File Server
# [{'id': '0d1d7ca2-135b-4327-9eb2-5525e99877a2', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '5e1673bf-d79d-47ed-aaed-a63bb1248f0b', 'outV': '64699f56-4d0f-459d-8113-1583643f195f', 'properties': {'related_service_score': 0.8722268}}]
# [{'id': 'b3e2dd9b-923b-4c33-b1e0-d1c51f626044', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '64699f56-4d0f-459d-8113-1583643f195f', 'outV': '5e1673bf-d79d-47ed-aaed-a63bb1248f0b', 'properties': {'related_service_score': 0.8722268}}]
# Adding related_service edges between Amazon CloudFront and Azure Content Delivery Network
# [{'id': '1b4055fb-7210-4776-a324-0bc09a0fb945', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'cc93b2bb-4dc0-4942-94c9-fa6b81d1f1f4', 'outV': '12649f64-82c1-4400-b607-5b757c2611f1', 'properties': {'related_service_score': 0.85199326}}]
# [{'id': 'b86037d9-7d4d-47a1-aacf-e563dc37f7ae', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '12649f64-82c1-4400-b607-5b757c2611f1', 'outV': 'cc93b2bb-4dc0-4942-94c9-fa6b81d1f1f4', 'properties': {'related_service_score': 0.85199326}}]
# Adding related_service edges between Amazon Simple Storage Service (S3) and Azure Storage
# [{'id': 'a674e066-0f95-4457-8010-4afe16cae6e9', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '6b06a33d-ffad-4c5a-889f-1a7aaf211b7a', 'outV': 'faa643e0-3858-41b8-8aa3-ec0d440107b9', 'properties': {'related_service_score': 0.8345205}}]
# [{'id': '0bdd34a8-0ec5-4f47-af3d-adcdea1bf4d0', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'faa643e0-3858-41b8-8aa3-ec0d440107b9', 'outV': '6b06a33d-ffad-4c5a-889f-1a7aaf211b7a', 'properties': {'related_service_score': 0.8345205}}]
# Adding related_service edges between Azure ExpressRoute and AWS Direct Connect
# [{'id': '8aac7564-ef7a-407a-8814-1261ff823cf3', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'b14009c9-d22a-4180-bf69-522580556246', 'outV': '56409c89-3791-4198-ac6f-edbea908a21a', 'properties': {'related_service_score': 0.83142847}}]
# [{'id': '9755d072-6a2f-4a9f-89a0-d7a893559e02', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '56409c89-3791-4198-ac6f-edbea908a21a', 'outV': 'b14009c9-d22a-4180-bf69-522580556246', 'properties': {'related_service_score': 0.83142847}}]
# Adding related_service edges between AWS Lake Formation and Azure Data Lake Analytics
# [{'id': '5a65c743-72d2-448d-9b8a-6369bf8ef821', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'd57dcd65-c031-4f44-bf78-0af94440f521', 'outV': '79c136f5-f61e-42e8-a663-c8042c48778f', 'properties': {'related_service_score': 0.81290454}}]
# [{'id': '4d8508ad-8fdd-4380-80bd-a46a1e0b16ff', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '79c136f5-f61e-42e8-a663-c8042c48778f', 'outV': 'd57dcd65-c031-4f44-bf78-0af94440f521', 'properties': {'related_service_score': 0.81290454}}]
# Adding related_service edges between Azure Data Box family and AWS Snow Family
# [{'id': '10d60733-7174-4c79-8f64-b2670e957848', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '106a0c5a-d39c-46a1-943a-65ab7152c457', 'outV': '1783300f-13da-41a7-97e4-2450ced106cf', 'properties': {'related_service_score': 0.80834025}}]
# [{'id': '14d2f67c-b793-448a-ade0-59e8694007ba', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '1783300f-13da-41a7-97e4-2450ced106cf', 'outV': '106a0c5a-d39c-46a1-943a-65ab7152c457', 'properties': {'related_service_score': 0.80834025}}]
# Adding related_service edges between Azure Machine Learning Services and Amazon SageMaker
# [{'id': '7d43bd9d-4011-44ad-8df9-c8c6381889d2', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '07e58db7-f250-4472-b98a-eef131828719', 'outV': '9996d722-70ba-4f6f-9359-996cc67b585b', 'properties': {'related_service_score': 0.7874167999999999}}]
# [{'id': 'c498ee1b-f068-41d1-b6f3-cc94b7fd34e6', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '9996d722-70ba-4f6f-9359-996cc67b585b', 'outV': '07e58db7-f250-4472-b98a-eef131828719', 'properties': {'related_service_score': 0.7874167999999999}}]
# Adding related_service edges between AWS IoT Things Graph and Azure IoT Fundamentals
# [{'id': 'e7a85d19-837f-41f0-b08a-115081b0b20a', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '1a4c1df6-72f2-4e08-aee5-b76385d75513', 'outV': 'd236f6d0-e73d-4cb1-ab3e-d38154d96107', 'properties': {'related_service_score': 0.7872448000000001}}]
# [{'id': 'e76cb4a7-8c92-4cd7-abce-44b0f6c59f03', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'd236f6d0-e73d-4cb1-ab3e-d38154d96107', 'outV': '1a4c1df6-72f2-4e08-aee5-b76385d75513', 'properties': {'related_service_score': 0.7872448000000001}}]
# Adding related_service edges between Azure Log Analytics and Amazon CloudSearch
# [{'id': '5c7796aa-4fd1-4083-96c4-490d73774559', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '8ddde875-71b7-4e59-b241-f7a5ec5bdf88', 'outV': 'a1d496ea-4c5f-4e01-92f1-a12afab28612', 'properties': {'related_service_score': 0.765726}}]
# [{'id': '03702513-0e18-4214-b8c2-ffde32c820c2', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'a1d496ea-4c5f-4e01-92f1-a12afab28612', 'outV': '8ddde875-71b7-4e59-b241-f7a5ec5bdf88', 'properties': {'related_service_score': 0.765726}}]
# Adding related_service edges between Azure StorSimple and AWS Storage Gateway
# [{'id': '71bc2124-86b0-4478-b01a-2a26597e4a2f', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '04810855-6145-4c68-b7d1-f12f174c0239', 'outV': '6ab7aba4-6002-4b7f-bb3d-e1ae5875ba75', 'properties': {'related_service_score': 0.74923253}}]
# [{'id': 'f0820944-8426-4183-97fb-b89c8d7c0e1a', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '6ab7aba4-6002-4b7f-bb3d-e1ae5875ba75', 'outV': '04810855-6145-4c68-b7d1-f12f174c0239', 'properties': {'related_service_score': 0.74923253}}]
# Adding related_service edges between AWS Directory Service and Azure Active Directory B2C
# [{'id': 'c5575dfa-69db-4b37-8010-5f2d077dc314', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '6b7d9263-b59e-4d30-b4ca-0bf055f2d902', 'outV': 'e6e629f9-1ff8-4619-9f67-ff6e279fc220', 'properties': {'related_service_score': 0.71572596}}]
# [{'id': '8c4d3444-a876-40af-a149-2909c13b6beb', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'e6e629f9-1ff8-4619-9f67-ff6e279fc220', 'outV': '6b7d9263-b59e-4d30-b4ca-0bf055f2d902', 'properties': {'related_service_score': 0.71572596}}]
# Adding related_service edges between Azure Database for MySQL and Amazon RDS
# [{'id': '86fc0b41-c390-4456-84db-e4494ad9598e', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '969f16ee-343e-4d58-8f84-f3f6b98ba125', 'outV': 'cae3dfbf-b224-4aba-b673-e1e4b02d00e0', 'properties': {'related_service_score': 0.7019025}}]
# [{'id': 'f6ecb74a-c628-4492-b59a-6875027d8cf6', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'cae3dfbf-b224-4aba-b673-e1e4b02d00e0', 'outV': '969f16ee-343e-4d58-8f84-f3f6b98ba125', 'properties': {'related_service_score': 0.7019025}}]
# Adding related_service edges between AWS Elastic Beanstalk and Azure App Service
# [{'id': '84e0047c-7e66-43c8-bd8c-10c11e5ec5ef', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'a0c9fc29-ce43-43bd-91f4-9588d27cb749', 'outV': '5b45d9fe-bafe-4438-bd22-db65460c3e4b', 'properties': {'related_service_score': 0.69986373}}]
# [{'id': '20adf717-db2c-4470-98ab-a86298cc96e0', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '5b45d9fe-bafe-4438-bd22-db65460c3e4b', 'outV': 'a0c9fc29-ce43-43bd-91f4-9588d27cb749', 'properties': {'related_service_score': 0.69986373}}]
# Adding related_service edges between Amazon DynamoDB and Azure Table Storage
# [{'id': 'f5a70d54-d6a0-4b7d-9587-96124d6e1e41', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': 'b5f0b8bf-23dd-4299-8660-7eecaffd3b00', 'outV': '3626ac81-70cc-4b48-90d1-5e89b99ecf91', 'properties': {'related_service_score': 0.6945710999999991}}]
# [{'id': '3e453f5d-fcb2-40fc-b500-f66c1dfd3e2e', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': '3626ac81-70cc-4b48-90d1-5e89b99ecf91', 'outV': 'b5f0b8bf-23dd-4299-8660-7eecaffd3b00', 'properties': {'related_service_score': 0.6945710999999991}}]
# Adding related_service edges between AWS Global Accelerator and Azure Traffic Manager
# [{'id': '0e159b5a-81ae-4314-a1b6-b0e712780a55', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '37ea32aa-fa97-4342-a260-499e363d22dd', 'outV': 'cb14cc65-4c12-4ce4-b3c5-267d9e4b4ae0', 'properties': {'related_service_score': 0.685134}}]
# [{'id': 'a6a1958b-2c07-43e9-85a6-f575b39a9639', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'cb14cc65-4c12-4ce4-b3c5-267d9e4b4ae0', 'outV': '37ea32aa-fa97-4342-a260-499e363d22dd', 'properties': {'related_service_score': 0.685134}}]
# Adding related_service edges between AWS Identity & Access Management and Azure Role-based access control
# [{'id': '2f9f400f-307c-44fe-a573-f50f046adc83', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'azure_service', 'outVLabel': 'aws_service', 'inV': '689e2a4a-7353-4b0b-b759-32f9716bb671', 'outV': 'a92398f1-3fa2-49f1-b429-738267c38ade', 'properties': {'related_service_score': 0.68069077}}]
# [{'id': 'f3d7774c-7525-4ffc-94b6-8ebaefbc6659', 'label': 'related_service', 'type': 'edge', 'inVLabel': 'aws_service', 'outVLabel': 'azure_service', 'inV': 'a92398f1-3fa2-49f1-b429-738267c38ade', 'outV': '689e2a4a-7353-4b0b-b759-32f9716bb671', 'properties': {'related_service_score': 0.68069077}}]

# %%
aws_azure_related.head()
# Out:
#      Cluster ID  Link Score  source file category_name  \
# 28            0    0.996641            0       Compute
# 181           0    0.996641            1       Compute
# 32            1    0.993355            0       Compute
# 180           1    0.993355            1       Compute
# 184           2    0.990656            1       Compute
#
#                                  name  \
# 28   Amazon Elastic Container Service
# 181         Azure Container Instances
# 32                          AWS Batch
# 180                       Azure Batch
# 184    Azure Kubernetes Service (AKS)
#
#                                      short_description  \
# 28                    Run and Manage Docker Containers
# 181        Easily run containers with a single command
# 32                         Run Batch Jobs at Any Scale
# 180  Cloud-scale job scheduling and compute management
# 184  Simplify the deployment, management, and opera...
#
#                                       long_description
# 28   Amazon Elastic Container Service (Amazon ECS) ...
# 181  Azure Container Instances offers the fastest a...
# 32   AWS Batch enables developers, scientists, and ...
# 180  Use Batch to run large-scale parallel and high...
# 184  Azure Kubernetes Service (AKS) manages your ho...

# %%
known_pairs = [
    ('AWS Lambda', 'Azure Functions')
]

for kp in known_pairs:
    aws_azure_df.loc[aws_azure_df['name'] == kp[0]]
# Out:
#     Cluster ID  Link Score  source file category_name        name  \
# 36          67         NaN            0       Compute  AWS Lambda
#
#                       short_description  \
# 36  Run your Code in Response to Events
#
#                                      long_description
# 36  AWS Lambda lets you run code without provision...
