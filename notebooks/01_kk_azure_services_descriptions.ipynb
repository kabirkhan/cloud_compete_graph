# %%
import json

import logging
from pathlib import Path
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_azure_services(output_filepath):
    assert output_filepath.endswith('.csv')

    AZURE_DOCS_URL = 'https://docs.microsoft.com/en-us/azure/'
    
    soup = BeautifulSoup(requests.get(AZURE_DOCS_URL + '#pivot=products').text, 'html.parser')
    
    azure_services = []
    categories_soup = soup.find('ul', {'id': 'products'}).find_all(
        'a', {'data-linktype': 'self-bookmark'}
    )
    categories_soup = categories_soup[1:]

    for category in categories_soup:
        category_id = category['href'][1:]

        # services = []
        category_soup = soup.find('ul', {'id': category_id})
        
        for link_soup in category_soup.find_all('a'):
            card_soup = link_soup.find('div', {'class': 'card'})
            service_name = card_soup.find('h3').text
            if 'Azure' not in service_name:
                service_name = f'Azure {service_name}'

            href = link_soup['href']
            if not href.startswith('https'):
                link = f"https://docs.microsoft.com{href}"
            
            short_description = card_soup.find('p').text.strip()
            try:
                service_page_soup = BeautifulSoup(requests.get(link).text, 'html.parser')
            except:
                print("Could not access page: ", link)
                print("Skipping")
                continue
                
            try:
                abstract = service_page_soup.find('div', {'class': 'abstract'}).find('p').text
            except:
                try:
                    abstract = service_page_soup.find('main').find('p').text
                except:
                    print('Could not get abstract or initial paragraph describing ', service_name)
                    abstract = short_description
                
            azure_services.append({
                'category_id': category_id,
                'category_name': category.text.strip(),
                'icon': f"{AZURE_DOCS_URL}{card_soup.find('img')['src']}",
                'name': service_name,
                'short_description': short_description,
                'long_description': abstract,
                'link': link
            })

    azure_services_df = pd.DataFrame(azure_services)
    azure_services_df = azure_services_df[[
        'category_id', 'category_name', 'name', 'short_description', 'long_description', 'link', 'icon'
    ]]
    return azure_services_df
#     azure_services_df.to_csv(output_filepath, index=False)
    
s = scrape_azure_services('t.csv')
s
# Out:
#     category_id     category_name                                  name  \
# 0       Compute           Compute          Azure Linux Virtual Machines
# 1       Compute           Compute        Azure Windows Virtual Machines
# 2       Compute           Compute                     Azure App Service
# 3       Compute           Compute                       Azure Functions
# 4       Compute           Compute                           Azure Batch
# 5       Compute           Compute             Azure Container Instances
# 6       Compute           Compute                  Azure Service Fabric
# 7       Compute           Compute      Azure Virtual Machine Scale Sets
# 8       Compute           Compute        Azure Kubernetes Service (AKS)
# 9       Compute           Compute                  Azure Cloud Services
# 10      Compute           Compute  Azure SQL Server on Virtual Machines
# 11      Compute           Compute     SAP HANA on Azure Large Instances
# 12      Compute           Compute                      Azure CycleCloud
# 13      network        Networking             Azure Networking Overview
# 14      network        Networking        Azure Content Delivery Network
# 15      network        Networking                    Azure ExpressRoute
# 16      network        Networking                             Azure DNS
# 17      network        Networking                 Azure Virtual Network
# 18      network        Networking                 Azure Traffic Manager
# 19      network        Networking                   Azure Load Balancer
# 20      network        Networking                     Azure VPN Gateway
# 21      network        Networking             Azure Application Gateway
# 22      network        Networking                 Azure DDoS Protection
# 23      network        Networking                 Azure Network Watcher
# 24      network        Networking                        Azure Firewall
# 25      network        Networking                     Azure Virtual WAN
# 26      network        Networking              Azure Front Door Service
# 27      storage           Storage                         Azure Storage
# 28      storage           Storage                      Azure StorSimple
# 29      storage           Storage          Azure Data Lake Storage Gen2
# ..          ...               ...                                   ...
# 165        mgmt  Management Tools           Azure Security & Compliance
# 166        mgmt  Management Tools                 Azure Network Watcher
# 167        mgmt  Management Tools                  Azure Service Health
# 168        mgmt  Management Tools                Microsoft Azure Portal
# 169        mgmt  Management Tools                Azure Resource Manager
# 170        mgmt  Management Tools                     Azure Cloud Shell
# 171        mgmt  Management Tools                      Azure mobile app
# 172        mgmt  Management Tools                          Azure Policy
# 173        mgmt  Management Tools                      Azure Blueprints
# 174        mgmt  Management Tools                  Azure Resource Graph
# 175        mgmt  Management Tools                 Azure Cost Management
# 176        mgmt  Management Tools            Azure Managed Applications
# 177        mgmt  Management Tools                         Azure Migrate
# 178        mgmt  Management Tools                         Azure Billing
# 179       media             Media                  Azure Media Services
# 180       media             Media                        Azure Encoding
# 181       media             Media    Azure Live and on-demand streaming
# 182       media             Media                    Azure Media Player
# 183       media             Media              Azure Content Protection
# 184       media             Media                 Azure Media Analytics
# 185       media             Media                   Azure Video Indexer
# 186   migration         Migration                   Azure Site Recovery
# 187   migration         Migration                 Azure Cost Management
# 188   migration         Migration      Azure Database Migration Service
# 189   migration         Migration                         Azure Migrate
# 190       stack       Azure Stack                  Azure Stack Operator
# 191       stack       Azure Stack                      Azure Stack User
# 192       other  Sovereign Clouds         Microsoft Azure US Government
# 193       other  Sovereign Clouds               Microsoft Azure Germany
# 194       other  Sovereign Clouds        Microsoft Azure China 21Vianet
#
#                                      short_description  \
# 0    Provision virtual machines of Ubuntu, Red Hat,...
# 1    Provision virtual machines for SQL Server, Sha...
# 2    Quickly create powerful cloud apps for web and...
# 3                  Process events with serverless code
# 4    Cloud-scale job scheduling and compute management
# 5          Easily run containers with a single command
# 6    Develop microservices and orchestrate containe...
# 7    Manage and scale up to thousands of Linux and ...
# 8    Simplify the deployment, management, and opera...
# 9    Create highly-available, infinitely-scalable c...
# 10        Host enterprise SQL Server apps in the cloud
# 11   Run the largest SAP HANA workloads of any hype...
# 12   Create, manage, operate, and optimize HPC and ...
# 13   An integrated view of the networking services ...
# 14   Ensure secure, reliable content delivery with ...
# 15   Dedicated private network fiber connections to...
# 16                       Host your DNS domain in Azure
# 17   Provision private networks, optionally connect...
# 18   Route incoming traffic for high performance an...
# 19   Deliver high availability and network performa...
# 20       Establish secure, cross-premises connectivity
# 21   Build secure, scalable, and highly available w...
# 22   Protect your applications from Distributed Den...
# 23   Network performance monitoring and diagnostics...
# 24   Highly available and scalable cloud-based netw...
# 25       Build secure global scale branch connectivity
# 26   Scalable and secure entry point to deliver glo...
# 27   Durable, highly available, and massively scala...
# 28   Lower costs with an enterprise hybrid cloud st...
# 29   Massively scalable, secure data lake storage b...
# ..                                                 ...
# 165  Enable threat detection and prevention through...
# 166  Network performance monitoring and diagnostics...
# 167  Get personalized guidance and support for when...
# 168  Build, manage, and monitor all Azure products ...
# 169         Simplify how you manage your app resources
# 170  Streamline Azure administration with a browser...
# 171  Stay connected to your Azure resourcesâanyti...
# 172  Implement corporate governance and standards a...
# 173  Deploy and update cloud environments in a repe...
# 174  Explore resources at scale with a rich query l...
# 175  Optimize what you spend on the cloud, while ma...
# 176             Simplify management of cloud offerings
# 177  Easily discover, assess, right-size, and migra...
# 178  Learn how to read/understand the usage and bil...
# 179  Encode, store, and stream video and audio at s...
# 180               Studio Grade encoding at cloud scale
# 181  Deliver content to virtually all devices with ...
# 182        A single player for all your playback needs
# 183  Securely deliver content using AES, PlayReady,...
# 184  Uncover insights from video files with speech ...
# 185  Make your multimedia more discoverable and acc...
# 186  Orchestrate protection and recovery of private...
# 187  Optimize what you spend on the cloud, while ma...
# 188      Reduce the complexity of your cloud migration
# 189  Easily discover, assess, right-size, and migra...
# 190  Deliver Azure services from your own datacente...
# 191  Use services and build applications for Azure ...
# 192  Build and host applications for US Government ...
# 193  Build and host applications in compliance with...
# 194  Build and host applications in compliance with...
#
#                                       long_description  \
# 0    Azure Linux Virtual Machines provides on-deman...
# 1    Azure Windows Virtual Machines provides on-dem...
# 2    Azure App Service enables you to build and hos...
# 3    Azure Functions is a serverless compute servic...
# 4    Use Batch to run large-scale parallel and high...
# 5    Azure Container Instances offers the fastest a...
# 6    Azure Service Fabric is a distributed systems ...
# 7    Azure virtual machine scale sets let you creat...
# 8    Azure Kubernetes Service (AKS) manages your ho...
# 9    Learn how to use Cloud Services to host and ru...
# 10   SQL Server on Azure virtual machines enables y...
# 11   SAP HANA on Azure (Large Instances) is a uniqu...
# 12   Azure CycleCloud is designed to enable enterpr...
# 13   Azure provides a variety of networking capabil...
# 14   Azure Content Delivery Network (CDN) is a glob...
# 15   Learn how to use ExpressRoute to set up a fast...
# 16   Learn how to use Azure DNS. Quickstarts, tutor...
# 17   Learn how to use Azure Virtual Network. Quicks...
# 18   Learn how to use Azure Traffic Manager. Quicks...
# 19   Learn how to use Azure Load Balancer. Quicksta...
# 20   Learn how to configure, create, and manage an ...
# 21   Learn how to deploy Application Gateway, an ap...
# 22   Distributed denial of service (DDoS) attacks a...
# 23   Learn how to use Azure Network Watcher. Quicks...
# 24   Learn how to deploy Azure Firewall, a cloud-ba...
# 25   Learn how to configure, create, and manage an ...
# 26   Azure Front Door Service provides a scalable a...
# 27   Azure Storage is a Microsoft-managed service p...
# 28   Learn how to use Azure StorSimple, an integrat...
# 29   âAzure Data Lake Storage Gen2 Preview is a s...
# ..                                                 ...
# 165  Security is integrated into every aspect of Az...
# 166  Learn how to use Azure Network Watcher. Quicks...
# 167  Azure Service Health is a suite of experiences...
# 168  Azure Service Health is a suite of experiences...
# 169  Learn how to use Resource Manager to deploy, m...
# 170  Azure Cloud Shell is an interactive, browser-a...
# 171  Azure Cloud Shell is an interactive, browser-a...
# 172  Azure Policy helps you manage and prevent IT i...
# 173  Azure Blueprints helps you deploy and update c...
# 174  Azure Resource Graph documentation helps you c...
# 175  Azure Cost Management is a cost management sol...
# 176  Azure Managed Applications enables you to offe...
# 177  The Azure Migrate service assesses on-premises...
# 178  Learn how to understand your Azure billing, mo...
# 179  Azure Media Services (AMS) is a cloud-based pl...
# 180  Azure Media Services provides multiple options...
# 181                                               Note
# 182  Azure Media Services supports many popular str...
# 183   You can use Azure Media Services to secure yo...
# 184  More organizations are using video as the pref...
# 185  Azure Video Indexer is a cloud application bui...
# 186  Azure Site Recovery orchestrates and manages d...
# 187  Azure Cost Management is a cost management sol...
# 188  The Azure Database Migration Service is a full...
# 189  The Azure Migrate service assesses on-premises...
# 190  Microsoft Azure Stack is a hybrid cloud platfo...
# 191  Azure Stack is a hybrid cloud platform that le...
# 192  Microsoft Azure Government delivers a cloud pl...
# 193  Microsoft Azure Germany is built on the Micros...
# 194  Microsoft Azure operated by 21Vianet is a clou...
#
#                                                   link  \
# 0    https://docs.microsoft.com/en-us/azure/virtual...
# 1    https://docs.microsoft.com/en-us/azure/virtual...
# 2    https://docs.microsoft.com/en-us/azure/app-ser...
# 3    https://docs.microsoft.com/en-us/azure/azure-f...
# 4        https://docs.microsoft.com/en-us/azure/batch/
# 5    https://docs.microsoft.com/en-us/azure/contain...
# 6    https://docs.microsoft.com/en-us/azure/service...
# 7    https://docs.microsoft.com/en-us/azure/virtual...
# 8          https://docs.microsoft.com/en-us/azure/aks/
# 9    https://docs.microsoft.com/en-us/azure/cloud-s...
# 10   https://docs.microsoft.com/en-us/azure/virtual...
# 11   https://docs.microsoft.com/en-us/azure/virtual...
# 12   https://docs.microsoft.com/en-us/azure/cyclecl...
# 13   https://docs.microsoft.com/en-us/azure/network...
# 14         https://docs.microsoft.com/en-us/azure/cdn/
# 15   https://docs.microsoft.com/en-us/azure/express...
# 16         https://docs.microsoft.com/en-us/azure/dns/
# 17   https://docs.microsoft.com/en-us/azure/virtual...
# 18   https://docs.microsoft.com/en-us/azure/traffic...
# 19   https://docs.microsoft.com/en-us/azure/load-ba...
# 20   https://docs.microsoft.com/en-us/azure/vpn-gat...
# 21   https://docs.microsoft.com/en-us/azure/applica...
# 22   https://docs.microsoft.com/en-us/azure/virtual...
# 23   https://docs.microsoft.com/en-us/azure/network...
# 24    https://docs.microsoft.com/en-us/azure/firewall/
# 25   https://docs.microsoft.com/en-us/azure/virtual...
# 26   https://docs.microsoft.com/en-us/azure/frontdoor/
# 27     https://docs.microsoft.com/en-us/azure/storage/
# 28   https://docs.microsoft.com/en-us/azure/storsim...
# 29   https://docs.microsoft.com/en-us/azure/storage...
# ..                                                 ...
# 165   https://docs.microsoft.com/en-us/azure/security/
# 166  https://docs.microsoft.com/en-us/azure/network...
# 167  https://docs.microsoft.com/en-us/azure/service...
# 168  https://docs.microsoft.com/en-us/azure/service...
# 169  https://docs.microsoft.com/en-us/azure/azure-r...
# 170  https://docs.microsoft.com/en-us/azure/cloud-s...
# 171  https://docs.microsoft.com/en-us/azure/cloud-s...
# 172  https://docs.microsoft.com/en-us/azure/governa...
# 173  https://docs.microsoft.com/en-us/azure/governa...
# 174  https://docs.microsoft.com/en-us/azure/governa...
# 175  https://docs.microsoft.com/en-us/azure/cost-ma...
# 176  https://docs.microsoft.com/en-us/azure/managed...
# 177  https://docs.microsoft.com/en-us/azure/migrate...
# 178    https://docs.microsoft.com/en-us/azure/billing/
# 179  https://docs.microsoft.com/en-us/azure/media-s...
# 180  https://docs.microsoft.com/en-us/azure/media-s...
# 181  https://docs.microsoft.com/en-us/azure/media-s...
# 182  https://docs.microsoft.com/en-us/azure/media-s...
# 183  https://docs.microsoft.com/en-us/azure/media-s...
# 184  https://docs.microsoft.com/en-us/azure/media-s...
# 185  https://docs.microsoft.com/en-us/azure/cogniti...
# 186  https://docs.microsoft.com/en-us/azure/site-re...
# 187  https://docs.microsoft.com/en-us/azure/cost-ma...
# 188  https://docs.microsoft.com/en-us/azure/dms/dms...
# 189  https://docs.microsoft.com/en-us/azure/migrate...
# 190  https://docs.microsoft.com/en-us/azure/azure-s...
# 191  https://docs.microsoft.com/en-us/azure/azure-s...
# 192  https://docs.microsoft.com/en-us/azure/azure-g...
# 193    https://docs.microsoft.com/en-us/azure/germany/
# 194      https://docs.microsoft.com/en-us/azure/china/
#
#                                                   icon
# 0    https://docs.microsoft.com/en-us/azure/media/i...
