# %%
import os
import pandas as pd

# %%
base_path = '../../data'

# %%
azure_aws = pd.read_csv(f'{base_path}/processed/azure_aws_dedupe/data_matching_output.csv')

# %%
azure_aws = azure_aws.sort_values(['Cluster ID', 'source file'])
azure_aws[azure_aws['Link Score'] > .30]
# Out:
#      Cluster ID  Link Score  source file  \
# 42            0    0.972938            0
# 255           0    0.972938            1
# 65            1    0.961049            0
# 148           1    0.961049            1
# 24            2    0.848177            0
# 169           2    0.848177            1
# 53            3    0.809725            0
# 283           3    0.809725            1
# 122           4    0.809075            0
# 299           4    0.809075            1
# 39            5    0.729706            0
# 198           5    0.729706            1
# 35            6    0.718253            0
# 215           6    0.718253            1
# 80            7    0.667962            0
# 183           7    0.667962            1
# 98            8    0.614738            0
# 261           8    0.614738            1
# 23            9    0.612466            0
# 200           9    0.612466            1
# 100          10    0.599301            0
# 212          10    0.599301            1
# 140          11    0.587109            0
# 195          11    0.587109            1
# 14           12    0.536286            0
# 170          12    0.536286            1
# 7            13    0.527059            0
# 175          13    0.527059            1
# 37           14    0.486130            0
# 194          14    0.486130            1
# 38           15    0.464938            0
# 191          15    0.464938            1
# 125          16    0.420464            0
# 294          16    0.420464            1
# 62           17    0.400307            0
# 268          17    0.400307            1
# 124          18    0.392852            0
# 222          18    0.392852            1
# 76           19    0.385905            0
# 176          19    0.385905            1
# 97           20    0.368148            0
# 286          20    0.368148            1
# 87           21    0.364884            0
# 168          21    0.364884            1
# 26           22    0.362913            0
# 236          22    0.362913            1
# 50           23    0.345570            0
# 156          23    0.345570            1
# 123          24    0.344176            0
# 298          24    0.344176            1
# 49           25    0.327829            0
# 256          25    0.327829            1
# 21           26    0.323186            0
# 185          26    0.323186            1
# 114          27    0.315780            0
# 285          27    0.315780            1
# 41           28    0.305918            0
# 171          28    0.305918            1
#
#                                                 name  \
# 42                    Azure Kubernetes Service (AKS)
# 255  Amazon Elastic Container Service for Kubernetes
# 65                                             Batch
# 148                                        AWS Batch
# 24                  Azure Database Migration Service
# 169                   AWS Database Migration Service
# 53                                Azure SQL Database
# 283                                       Amazon RDS
# 122                               Speech Translation
# 299                                 Amazon Translate
# 39                                     Azure IoT Hub
# 198                             AWS IoT Things Graph
# 35                                   Azure Functions
# 215                                       AWS Lambda
# 80                               Container Instances
# 183                                      AWS Fargate
# 98                                      File Storage
# 261               Amazon FSx for Windows File Server
# 23                           Azure Data Lake Storage
# 200                               AWS Lake Formation
# 100                                        Key Vault
# 212                              AWS Secrets Manager
# 140                     Windows 10 IoT Core Services
# 195                        AWS IoT Device Management
# 14                                    Azure Batch AI
# 170                           AWS Deep Learning AMIs
# 7                             Azure Active Directory
# 175                            AWS Directory Service
# 37                                 Azure IoT Central
# 194                          AWS IoT Device Defender
# 38                                    Azure IoT Edge
# 191                                AWS IoT Analytics
# 125                                          Storage
# 294               Amazon Simple Storage Service (S3)
# 62                            Azure Stream Analytics
# 268                                   Amazon Kinesis
# 124                                       StorSimple
# 222                              AWS Storage Gateway
# 76                                    Cloud Services
# 176                            AWS Elastic Beanstalk
# 97                                              Face
# 286                               Amazon Rekognition
# 87                                          Data Box
# 168                                     AWS DataSync
# 26                          Azure Database for MySQL
# 236                                    Amazon Aurora
# 50                                   Azure Pipelines
# 156                                    AWS CodeBuild
# 123                                   Speech to Text
# 298                                Amazon Transcribe
# 49                                Azure NetApp Files
# 256                 Amazon Elastic File System (EFS)
# 21                                         Azure DNS
# 185                           AWS Global Accelerator
# 114                               SQL Data Warehouse
# 285                                  Amazon Redshift
# 41                                   Azure Kinect DK
# 171                                     AWS DeepLens
#
#                                             categories  \
# 42                           ['Compute', 'Containers']
# 255                                        ['Compute']
# 65                                         ['Compute']
# 148                                        ['Compute']
# 24               ['Databases', 'Migration & Transfer']
# 169              ['Databases', 'Migration & Transfer']
# 53                                       ['Databases']
# 283                                      ['Databases']
# 122                          ['AI + Machine Learning']
# 299                          ['AI + Machine Learning']
# 39                              ['Internet of Things']
# 198                             ['Internet of Things']
# 35     ['Compute', 'Containers', 'Internet of Things']
# 215                                        ['Compute']
# 80                           ['Compute', 'Containers']
# 183                                        ['Compute']
# 98                                         ['Storage']
# 261                                        ['Storage']
# 23                            ['Analytics', 'Storage']
# 200                                      ['Analytics']
# 100                ['Security, Identity & Compliance']
# 212                ['Security, Identity & Compliance']
# 140                             ['Internet of Things']
# 195                             ['Internet of Things']
# 14                ['AI + Machine Learning', 'Compute']
# 170                          ['AI + Machine Learning']
# 7    ['Security, Identity & Compliance', 'Security,...
# 175                ['Security, Identity & Compliance']
# 37                              ['Internet of Things']
# 194                             ['Internet of Things']
# 38                              ['Internet of Things']
# 191                             ['Internet of Things']
# 125                                        ['Storage']
# 294                                        ['Storage']
# 62                 ['Analytics', 'Internet of Things']
# 268                                      ['Analytics']
# 124                                        ['Storage']
# 222                                        ['Storage']
# 76                                         ['Compute']
# 176                                        ['Compute']
# 97                           ['AI + Machine Learning']
# 286                          ['AI + Machine Learning']
# 87                 ['Migration & Transfer', 'Storage']
# 168                           ['Migration & Transfer']
# 26                                       ['Databases']
# 236                                      ['Databases']
# 50                       ['Developer Tools', 'DevOps']
# 156                                ['Developer Tools']
# 123                          ['AI + Machine Learning']
# 298                          ['AI + Machine Learning']
# 49                                         ['Storage']
# 256                                        ['Storage']
# 21                   ['Networking & Content Delivery']
# 185                  ['Networking & Content Delivery']
# 114                         ['Analytics', 'Databases']
# 285                         ['Analytics', 'Databases']
# 41   ['AI + Machine Learning', 'Internet of Things'...
# 171                          ['AI + Machine Learning']
#
#                                      short_description  \
# 42   Simplify the deployment, management, and opera...
# 255                      Run Managed Kubernetes on AWS
# 65   Cloud-scale job scheduling and compute management
# 148                        Run Batch Jobs at Any Scale
# 24   Simplify on-premises database migration to the...
# 169            Migrate Databases with Minimal Downtime
# 53        Managed relational SQL Database as a service
# 283  Managed Relational Database Service for MySQL,...
# 122  Easily integrate real-time speech translation ...
# 299            Natural and Fluent Language Translation
# 39   Connect, monitor and manage billions of IoT as...
# 198            Easily connect devices and web services
# 35                 Process events with serverless code
# 215                Run your Code in Response to Events
# 80   Easily run containers on Azure without managin...
# 183  Run Containers without Managing Servers or Clu...
# 98   File shares that use the standard SMB 3.0 prot...
# 261           Fully managed Windows native file system
# 23   Massively scalable, secure data lake functiona...
# 200                   Build a secure data lake in days
# 100  Safeguard and maintain control of keys and oth...
# 212               Rotate, Manage, and Retrieve Secrets
# 140  Long-term OS support and services to manage de...
# 195  Onboard, Organize, and Remotely Manage IoT Dev...
# 14   Easily experiment and train your deep learning...
# 170                 Quickly Start Deep Learning on EC2
# 7    Synchronize on-premises directories and enable...
# 175                   Host and Manage Active Directory
# 37   Experience the simplicity of SaaS for IoT, wit...
# 194                Security Management for IoT Devices
# 38   Extend cloud intelligence and analytics to edg...
# 191                          Analytics for IoT Devices
# 125  Durable, highly available, and massively scala...
# 294                      Scalable Storage in the Cloud
# 62   Real-time data stream processing from millions...
# 268                 Work with Real-time Streaming Data
# 124  Lower costs with an enterprise hybrid cloud st...
# 222                         Hybrid Storage Integration
# 76   Create highly-available, infinitely-scalable c...
# 176                            Run and Manage Web Apps
# 97   Detect, identify, analyze, organize, and tag f...
# 286                            Analyze Image and Video
# 87   Secure, ruggedized appliance for Azure data tr...
# 168                 Simple, fast, online data transfer
# 26   Managed MySQL database service for app developers
# 236       High Performance Managed Relational Database
# 50   Continuously build, test, and deploy to any pl...
# 156                                Build and Test Code
# 123  The Speech to Text API is part of Azure Cognit...
# 298                       Automatic Speech Recognition
# 49   Powerful, hybrid network file system (NFS) fil...
# 256                  Fully managed file system for EC2
# 21                       Host your DNS domain in Azure
# 185   Improve application availability and performance
# 114  Elastic data warehouse as a service with enter...
# 285      Fast, Simple, Cost-effective Data Warehousing
# 41   Build computer vision and speech models using ...
# 171                 Deep Learning Enabled Video Camera
#
#                                       long_description
# 42   Easily manage Kubernetes with Azure Kubernetes...
# 255  Amazon Elastic Container Service for Kubernete...
# 65   Learn about Azure Batch, a Microsoft cloud com...
# 148  AWS Batch enables developers, scientists, and ...
# 24   For assessment and migration, choose Azure Dat...
# 169  AWS Database Migration Service helps you migra...
# 53   Microsoft Azure Cloud SQL Database is the deve...
# 283  Amazon Relational Database Service (Amazon RDS...
# 122  The Speech Translation from Microsoft Azure al...
# 299  Amazon Translate is a neural machine translati...
# 39   Manage billions of IoT devices to with Azure I...
# 198  AWS IoT Things Graph is a service that makes i...
# 35   Build apps faster with a serverless architectu...
# 215  AWS Lambda lets you run code without provision...
# 80   Easily run application containers in the cloud...
# 183  AWS Fargate is a compute engine for Amazon ECS...
# 98   Try Azure File Storage for managed file shares...
# 261  Amazon FSx for Windows File Server provides a ...
# 23   Azure Data Lake Storage Gen2 is highly scalabl...
# 200  AWS Lake Formation is a service that makes it ...
# 100  Safeguard cryptographic keys and other secrets...
# 212  AWS Secrets Manager helps you protect secrets ...
# 140  Secure your network and devices, manage device...
# 195  As many IoT deployments consist of hundreds of...
# 14   Train Deep Learning and other AI models with B...
# 170  The AWS Deep Learning AMIs provide machine lea...
# 7    Azure Active Directory provides an identity pl...
# 175  AWS Directory Service for Microsoft Active Dir...
# 37   Azure IoT Central is an IoT SaaS solution to c...
# 194  AWS IoT Device Defender is a fully managed ser...
# 38   Connect cloud intelligence to your edge device...
# 191  AWS IoT Analytics is a fully-managed service t...
# 125  Learn about Azure Storage, a durable, highly a...
# 294  Amazon Simple Storage Service (Amazon S3) is a...
# 62   Learn about Azure Stream Analytics, an event d...
# 268  Amazon Kinesis makes it easy to collect, proce...
# 124  Learn about Azure StorSimple, a hybrid online ...
# 222  AWS Storage Gateway is a hybrid storage servic...
# 76   Learn about Azure Cloud Services, which help y...
# 176   AWS Elastic Beanstalk is an easy-to-use servi...
# 97   Build facial recognition software into your ap...
# 286  Amazon Rekognition makes it easy to add image ...
# 87   Use Azure Data Box products to transfer large ...
# 168  AWS DataSync is a data transfer service that m...
# 26   Azure Database for MySQL is a fully-managed da...
# 236  Amazon Aurora is a MySQL and PostgreSQL-compat...
# 50   Get 10 free parallel jobs for cloud-based CI/C...
# 156  AWS CodeBuild is a fully managed continuous in...
# 123  Build smarter apps. Speech to Text transcripti...
# 298  Amazon Transcribe is an automatic speech recog...
# 49   Discover Azure Netapp Files—the hybrid network...
# 256  Amazon Elastic File System (Amazon EFS) provid...
# 21   The Microsoft global network of name servers h...
# 185  AWS Global Accelerator is a networking service...
# 114  Get started with Azure SQL Data Warehouse for ...
# 285  Amazon Redshift is a fast, scalable data wareh...
# 41   Developers: Build advanced computer vision and...
# 171  AWS DeepLens helps put deep learning in the ha...

# %%
# azure_aws[azure_aws['name'] == 'Azure Cosmos DB']
azure_aws[azure_aws['name'].isin(['Azure Functions', 'AWS Lambda'])].to_dict(orient='records')
# Out:
# [{'Cluster ID': 6,
#   'Link Score': 0.71825284,
#   'source file': 0,
#   'name': 'Azure Functions',
#   'categories': "['Compute', 'Containers', 'Internet of Things']",
#   'short_description': 'Process events with serverless code',
#   'long_description': 'Build apps faster with a serverless architecture. Azure Functions delivers an event-driven serverless compute experience with scale on demand.'},
#  {'Cluster ID': 175,
#   'Link Score': nan,
#   'source file': 1,
#   'name': 'AWS Lambda',
#   'categories': "['Compute']",
#   'short_description': 'Run your Code in Response to Events',
#   'long_description': 'AWS Lambda lets you run code without provisioning or managing servers. You pay only for the compute time you consume - there is no charge when your code is not running. \nWith Lambda, you can run code for virtually any type of application or backend service - all with zero administration. Just upload your code and Lambda takes care of everything required to run and scale your code with high availability. You can set up your code to automatically trigger from other AWS services or call it directly from any web or mobile app. \nAWS Lambda automatically runs your code without requiring you to provision or manage servers. Just write the code and upload it to Lambda.'}]

# %%
for prop in ['name', 'categories', 'short_description', 'long_description']:
    azure_aws.loc[(azure_aws['Cluster ID'] == 6) & (azure_aws['source file'] == 1), prop] = list(azure_aws[azure_aws['Cluster ID'] == 175][prop])[0]
azure_aws.loc[(azure_aws['Cluster ID'] == 6) & (azure_aws['source file'] == 1), prop]
# Out:
# 215    AWS Lambda lets you run code without provision...
# Name: long_description, dtype: object

# %%
azure_aws.to_csv(f'{base_path}/processed/azure_aws_dedupe/data_matching_output.csv', index=False)
