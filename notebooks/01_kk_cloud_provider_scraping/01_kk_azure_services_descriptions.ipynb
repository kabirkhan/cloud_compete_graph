# %%
import json

import logging
from pathlib import Path
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_azure_services(output_filepath):
    assert output_filepath.endswith('.csv')

    AZURE_DOCS_URL = 'https://docs.microsoft.com/en-us/azure/'
    
    soup = BeautifulSoup(requests.get(AZURE_DOCS_URL + '#pivot=products').text, 'html.parser')
    
    azure_services = []
    categories_soup = soup.find('ul', {'id': 'products'}).find_all(
        'a', {'data-linktype': 'self-bookmark'}
    )
    categories_soup = categories_soup[1:]

    for category in categories_soup:
        category_id = category['href'][1:]

        # services = []
        category_soup = soup.find('ul', {'id': category_id})
        
        for link_soup in category_soup.find_all('a'):
            card_soup = link_soup.find('div', {'class': 'card'})
            service_name = card_soup.find('h3').text
            if 'Azure' not in service_name:
                service_name = f'Azure {service_name}'

            href = link_soup['href']
            if not href.startswith('https'):
                link = f"https://docs.microsoft.com{href}"
            
            short_description = card_soup.find('p').text.strip()
            try:
                service_page_soup = BeautifulSoup(requests.get(link).text, 'html.parser')
            except:
                print("Could not access page: ", link)
                print("Skipping")
                continue
                
            try:
                abstract = service_page_soup.find('div', {'class': 'abstract'}).find('p').text
            except:
                try:
                    abstract = service_page_soup.find('main').find('p').text
                except:
                    print('Could not get abstract or initial paragraph describing ', service_name)
                    abstract = short_description
                
            azure_services.append({
                'category_id': category_id,
                'category_name': category.text.strip(),
                'icon': f"{AZURE_DOCS_URL}{card_soup.find('img')['src']}",
                'name': service_name,
                'short_description': short_description,
                'long_description': abstract,
                'link': link
            })

    azure_services_df = pd.DataFrame(azure_services)
    azure_services_df = azure_services_df[[
        'category_id', 'category_name', 'name', 'short_description', 'long_description', 'link', 'icon'
    ]]
    return azure_services_df
#     azure_services_df.to_csv(output_filepath, index=False)
    
s = scrape_azure_services('t.csv')
s

# %%
base_url = 'https://azure.microsoft.com'

soup = BeautifulSoup(requests.get(f'{base_url}/services').text, 'html.parser')
products_soup = soup.find('div', {'id': 'products-list'})

# %%
services = []

for cat in products_soup.find_all('div', {'class': 'row-size3'}):
    nextNode = cat
    cat_id = cat.find('h2', {'class': 'product-category'})['id']
    cat_name = cat.find('h2', {'class': 'product-category'}).text.strip()
    try:
        cat_link = f"{base_url}{cat.find('a')['href']}"
    except:
        cat_link = ''
    while True:
        nextNode = nextNode.nextSibling.nextSibling

        try:
            class_names = nextNode.get('class')
        except:
            break
        
        if 'row-size2' in class_names:
            names = [h2.text.strip() for h2 in nextNode.find_all('h2')]
            links = [a['href'] for a in nextNode.find_all('a')]
            descs = [p.text.strip() for p in nextNode.find_all('p')]
            
            for i in range(len(names)):
                link = f"{base_url}{links[i]}"
                svc_soup = BeautifulSoup(requests.get(link).text, 'html.parser')
                long_desc = svc_soup.find('meta', {'name': 'description'})['content']
                
                try:
                    docs_btn = svc_soup.find('nav', {'class': 'sub-nav'}).find(text='Documentation').parent
                except:
                    try:
                        docs_btn = svc_soup.find('nav', {'id': 'global-subnav'}).find_all('a', {'class', 'external-link'})[-1]
                    except:
                        try:
                            docs_btn = svc_soup.find('nav', {'class': 'sub-nav'}).find(text='Developer Guide').parent
                        except:
                            continue

                if docs_btn and docs_btn.get('href'):
                    documentation_links = docs_btn['href']
                else:
                    print('no docs link')
                    print(docs_btn.nextSibling)
                    documentation_links = [a['href'] for a in docs_btn.nextSibling.nextSibling.find_all('a')]
                
                services.append({
                    'category_id': cat_id,
                    'category_name': cat_name,
                    'category_link': cat_link,
                    'name': names[i],
                    'link': link,
                    'short_description': descs[i],
                    'long_description': long_desc,
                    'icon': '',
                    'documentation_links': documentation_links
                })
        else:
            break
services
# Out:
# https://azure.microsoft.com/en-us/services/batch-ai/
# https://azure.microsoft.com/en-us/services/bot-service/
# https://azure.microsoft.com/en-us/services/databricks/
# https://azure.microsoft.com/en-us/services/search/
# https://azure.microsoft.com/en-us/services/cognitive-services/autosuggest/
# https://azure.microsoft.com/en-us/services/cognitive-services/bing-custom-search/
# https://azure.microsoft.com/en-us/services/cognitive-services/bing-entity-search-api/
# https://azure.microsoft.com/en-us/services/cognitive-services/bing-image-search-api/
# https://azure.microsoft.com/en-us/services/cognitive-services/bing-news-search-api/
# https://azure.microsoft.com/en-us/services/cognitive-services/spell-check/
# https://azure.microsoft.com/en-us/services/cognitive-services/bing-video-search-api/
# https://azure.microsoft.com/en-us/services/cognitive-services/bing-visual-search/
# https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/
# https://azure.microsoft.com/en-us/services/cognitive-services/
# https://azure.microsoft.com/en-us/services/cognitive-services/computer-vision/
# https://azure.microsoft.com/en-us/services/cognitive-services/content-moderator/
# https://azure.microsoft.com/en-us/services/cognitive-services/custom-speech-service/
# https://azure.microsoft.com/en-us/services/cognitive-services/custom-vision-service/
# https://azure.microsoft.com/en-us/services/virtual-machines/data-science-virtual-machines/
# https://azure.microsoft.com/en-us/services/cognitive-services/emotion/
# https://azure.microsoft.com/en-us/services/cognitive-services/face/
# https://azure.microsoft.com/en-us/services/machine-learning-service/
# https://azure.microsoft.com/en-us/services/machine-learning-studio/
# https://azure.microsoft.com/en-us/services/genomics/
# https://azure.microsoft.com/en-us/services/cognitive-services/translator-speech-api/
# https://azure.microsoft.com/en-us/services/cognitive-services/language-understanding-intelligent-service/
# https://azure.microsoft.com/en-us/services/cognitive-services/linguistic-analysis-api/
# https://azure.microsoft.com/en-us/services/cognitive-services/qna-maker/
# https://azure.microsoft.com/en-us/services/cognitive-services/speaker-recognition/
# https://azure.microsoft.com/en-us/services/cognitive-services/speech-translation/
# https://azure.microsoft.com/en-us/services/cognitive-services/speech-to-text/
# https://azure.microsoft.com/en-us/services/cognitive-services/text-analytics/
# https://azure.microsoft.com/en-us/services/cognitive-services/text-to-speech/
# https://azure.microsoft.com/en-us/services/cognitive-services/translator-text-api/
# https://azure.microsoft.com/en-us/services/media-services/video-indexer/
# https://azure.microsoft.com/en-us/services/kinect-dk/
# https://azure.microsoft.com/en-us/services/databricks/
# https://azure.microsoft.com/en-us/services/stream-analytics/
# https://azure.microsoft.com/en-us/services/sql-data-warehouse/
# https://azure.microsoft.com/en-us/services/hdinsight/
# https://azure.microsoft.com/en-us/services/data-factory/
# https://azure.microsoft.com/en-us/services/data-lake-analytics/
# https://azure.microsoft.com/en-us/services/event-hubs/
# https://azure.microsoft.com/en-us/services/power-bi-embedded/
# https://azure.microsoft.com/en-us/services/analysis-services/
# https://azure.microsoft.com/en-us/services/hdinsight/r-server/
# https://azure.microsoft.com/en-us/services/data-catalog/
# https://azure.microsoft.com/en-us/services/storage/data-lake-storage/
# https://azure.microsoft.com/en-us/services/data-explorer/
# https://azure.microsoft.com/en-us/services/virtual-machines/
# no docs link
#
#
# https://azure.microsoft.com/en-us/services/virtual-machine-scale-sets/
# https://azure.microsoft.com/en-us/services/kubernetes-service/
# https://azure.microsoft.com/en-us/services/functions/
# https://azure.microsoft.com/en-us/services/service-fabric/
# https://azure.microsoft.com/en-us/services/app-service/
# https://azure.microsoft.com/en-us/services/container-instances/
# https://azure.microsoft.com/en-us/services/batch/
# https://azure.microsoft.com/en-us/services/batch-ai/
# https://azure.microsoft.com/en-us/services/virtual-machines/sql-server/
# https://azure.microsoft.com/en-us/services/cloud-services/
# https://azure.microsoft.com/en-us/services/virtual-machines/sap-hana/
# https://azure.microsoft.com/en-us/services/app-service/web/
# https://azure.microsoft.com/en-us/services/app-service/mobile/
# https://azure.microsoft.com/en-us/services/app-service/api/
# https://azure.microsoft.com/en-us/services/virtual-machines/linux-and-open/
# https://azure.microsoft.com/en-us/features/azure-cyclecloud/
# https://azure.microsoft.com/en-us/services/kubernetes-service/
# https://azure.microsoft.com/en-us/services/functions/
# https://azure.microsoft.com/en-us/services/service-fabric/
# https://azure.microsoft.com/en-us/services/container-instances/
# https://azure.microsoft.com/en-us/services/container-registry/
# https://azure.microsoft.com/en-us/services/app-service/web/
# https://azure.microsoft.com/en-us/services/app-service/mobile/
# https://azure.microsoft.com/en-us/services/app-service/api/
# https://azure.microsoft.com/en-us/services/app-service/containers/
# https://azure.microsoft.com/en-us/services/virtual-machines/sql-server/
# https://azure.microsoft.com/en-us/services/sql-database/
# https://azure.microsoft.com/en-us/services/cosmos-db/
# https://azure.microsoft.com/en-us/services/sql-data-warehouse/
# https://azure.microsoft.com/en-us/services/data-factory/
# https://azure.microsoft.com/en-us/services/cache/
# https://azure.microsoft.com/en-us/services/sql-server-stretch-database/
# https://azure.microsoft.com/en-us/services/storage/tables/
# https://azure.microsoft.com/en-us/services/postgresql/
# https://azure.microsoft.com/en-us/services/mariadb/
# https://azure.microsoft.com/en-us/services/mysql/
# https://azure.microsoft.com/en-us/services/database-migration/
# https://azure.microsoft.com/en-us/products/visual-studio/
# https://azure.microsoft.com/en-us/products/visual-studio-code/
# https://azure.microsoft.com/en-us/downloads/
# https://azure.microsoft.com/en-us/services/devops/
# https://azure.microsoft.com/en-us/tools/
# https://azure.microsoft.com/en-us/services/devops/pipelines/
# https://azure.microsoft.com/en-us/services/lab-services/
# https://azure.microsoft.com/en-us/services/devtest-lab/
# https://azure.microsoft.com/en-us/products/developer-tool-integrations/
# https://azure.microsoft.com/en-us/services/devops/
# https://azure.microsoft.com/en-us/services/devops/pipelines/
# https://azure.microsoft.com/en-us/services/devops/boards/
# https://azure.microsoft.com/en-us/services/devops/repos/
# https://azure.microsoft.com/en-us/services/devops/artifacts/
# https://azure.microsoft.com/en-us/services/devops/test-plans/
# https://azure.microsoft.com/en-us/services/devtest-lab/
# https://azure.microsoft.com/en-us/products/devops-tool-integrations/
# https://azure.microsoft.com/en-us/services/active-directory/
# https://azure.microsoft.com/en-us/services/information-protection/
# https://azure.microsoft.com/en-us/services/active-directory-ds/
# https://azure.microsoft.com/en-us/services/active-directory-b2c/
# https://azure.microsoft.com/en-us/services/event-grid/
# https://azure.microsoft.com/en-us/services/logic-apps/
# https://azure.microsoft.com/en-us/services/api-management/
# https://azure.microsoft.com/en-us/services/service-bus/
# https://azure.microsoft.com/en-us/services/functions/
# https://azure.microsoft.com/en-us/services/iot-hub/
# https://azure.microsoft.com/en-us/services/iot-edge/
# https://azure.microsoft.com/en-us/services/iot-central/
# https://azure.microsoft.com/en-us/features/iot-accelerators/
# https://azure.microsoft.com/en-us/services/azure-sphere/
# https://azure.microsoft.com/en-us/services/time-series-insights/
# https://azure.microsoft.com/en-us/services/azure-maps/
# https://azure.microsoft.com/en-us/services/event-grid/
# https://azure.microsoft.com/en-us/services/windows-10-iot-core/
# https://azure.microsoft.com/en-us/services/machine-learning-service/
# https://azure.microsoft.com/en-us/services/machine-learning-studio/
# https://azure.microsoft.com/en-us/services/stream-analytics/
# https://azure.microsoft.com/en-us/services/logic-apps/
# https://azure.microsoft.com/en-us/services/notification-hubs/
# https://azure.microsoft.com/en-us/services/cosmos-db/
# https://azure.microsoft.com/en-us/services/api-management/
# https://azure.microsoft.com/en-us/services/digital-twins/
# https://azure.microsoft.com/en-us/services/kinect-dk/
# https://azure.microsoft.com/en-us/services/backup/
# https://azure.microsoft.com/en-us/services/site-recovery/
# https://azure.microsoft.com/en-us/services/advisor/
# https://azure.microsoft.com/en-us/services/scheduler/
# https://azure.microsoft.com/en-us/services/automation/
# https://azure.microsoft.com/en-us/services/traffic-manager/
# https://azure.microsoft.com/en-us/services/monitor/
# https://azure.microsoft.com/en-us/services/network-watcher/
# https://azure.microsoft.com/en-us/features/service-health/
# https://azure.microsoft.com/en-us/features/azure-portal/
# https://azure.microsoft.com/en-us/features/resource-manager/
# https://azure.microsoft.com/en-us/features/cloud-shell/
# https://azure.microsoft.com/en-us/features/azure-portal/mobile-app/
# https://azure.microsoft.com/en-us/services/azure-policy/
# https://azure.microsoft.com/en-us/services/cost-management/
# https://azure.microsoft.com/en-us/services/managed-applications/
# https://azure.microsoft.com/en-us/services/azure-migrate/
# https://azure.microsoft.com/en-us/services/blueprints/
# https://azure.microsoft.com/en-us/services/cdn/
# https://azure.microsoft.com/en-us/services/media-services/
# https://azure.microsoft.com/en-us/services/media-services/encoding/
# https://azure.microsoft.com/en-us/services/media-services/live-on-demand/
# https://azure.microsoft.com/en-us/services/media-services/media-player/
# https://azure.microsoft.com/en-us/services/media-services/content-protection/
# https://azure.microsoft.com/en-us/services/media-services/media-analytics/
# https://azure.microsoft.com/en-us/services/media-services/video-indexer/
# https://azure.microsoft.com/en-us/services/site-recovery/
# https://azure.microsoft.com/en-us/services/cost-management/
# https://azure.microsoft.com/en-us/services/database-migration/
# https://azure.microsoft.com/en-us/services/azure-migrate/
# https://azure.microsoft.com/en-us/services/storage/databox/
# https://azure.microsoft.com/en-us/services/digital-twins/
# https://azure.microsoft.com/en-us/services/spatial-anchors/
# https://azure.microsoft.com/en-us/services/kinect-dk/
# https://azure.microsoft.com/en-us/services/remote-rendering/
# https://azure.microsoft.com/en-us/services/app-service/
# https://azure.microsoft.com/en-us/services/azure-maps/
# https://azure.microsoft.com/en-us/services/notification-hubs/
# https://azure.microsoft.com/en-us/services/app-service/web/
# https://azure.microsoft.com/en-us/services/app-service/mobile/
# https://azure.microsoft.com/en-us/services/app-service/api/
# https://azure.microsoft.com/en-us/features/azure-portal/mobile-app/
# https://azure.microsoft.com/en-us/services/app-center/
# https://azure.microsoft.com/en-us/features/xamarin/
# https://azure.microsoft.com/en-us/services/app-service/containers/
# https://azure.microsoft.com/en-us/services/cdn/
# https://azure.microsoft.com/en-us/services/expressroute/
# https://azure.microsoft.com/en-us/services/dns/
# https://azure.microsoft.com/en-us/services/virtual-network/
# https://azure.microsoft.com/en-us/services/traffic-manager/
# https://azure.microsoft.com/en-us/services/load-balancer/
# https://azure.microsoft.com/en-us/services/vpn-gateway/
# https://azure.microsoft.com/en-us/services/application-gateway/
# https://azure.microsoft.com/en-us/services/ddos-protection/
# https://azure.microsoft.com/en-us/services/network-watcher/
# https://azure.microsoft.com/en-us/services/azure-firewall/
# https://azure.microsoft.com/en-us/services/virtual-wan/
# https://azure.microsoft.com/en-us/services/frontdoor/
# https://azure.microsoft.com/en-us/services/active-directory/
# https://azure.microsoft.com/en-us/services/information-protection/
# https://azure.microsoft.com/en-us/services/active-directory-ds/
# https://azure.microsoft.com/en-us/services/key-vault/
# https://azure.microsoft.com/en-us/services/security-center/
# https://azure.microsoft.com/en-us/services/azure-dedicated-hsm/
# https://azure.microsoft.com/en-us/services/vpn-gateway/
# https://azure.microsoft.com/en-us/services/application-gateway/
# https://azure.microsoft.com/en-us/services/ddos-protection/
# https://azure.microsoft.com/en-us/services/azure-sentinel/
# https://azure.microsoft.com/en-us/services/storage/
# https://azure.microsoft.com/en-us/services/backup/
# https://azure.microsoft.com/en-us/services/storsimple/
# https://azure.microsoft.com/en-us/services/storage/data-lake-storage/
# https://azure.microsoft.com/en-us/services/storage/blobs/
# https://azure.microsoft.com/en-us/services/storage/disks/
# https://azure.microsoft.com/en-us/services/managed-disks/
# https://azure.microsoft.com/en-us/services/storage/queues/
# https://azure.microsoft.com/en-us/services/storage/files/
# https://azure.microsoft.com/en-us/services/storage/databox/
# https://azure.microsoft.com/en-us/services/storage/avere-vfxt/
# https://azure.microsoft.com/en-us/features/storage-explorer/
# https://azure.microsoft.com/en-us/services/storage/archive/
# https://azure.microsoft.com/en-us/services/storage/netapp/
# https://azure.microsoft.com/en-us/services/app-service/
# https://azure.microsoft.com/en-us/services/cdn/
# https://azure.microsoft.com/en-us/services/search/
# https://azure.microsoft.com/en-us/services/notification-hubs/
# https://azure.microsoft.com/en-us/services/api-management/
# https://azure.microsoft.com/en-us/services/app-service/web/
# https://azure.microsoft.com/en-us/services/app-service/mobile/
# https://azure.microsoft.com/en-us/services/app-service/api/
# https://azure.microsoft.com/en-us/services/app-service/containers/
# https://azure.microsoft.com/en-us/services/signalr-service/
# [{'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Azure Batch AI',
#   'link': 'https://azure.microsoft.com/en-us/services/batch-ai/',
#   'short_description': 'Easily experiment and train your deep learning and AI models in parallel at scale',
#   'long_description': 'Train Deep Learning and other AI models with Batch AI in parallel, using any framework. Azure Batch AI handles the heavy lifting for easy experimentation, at scale.',
#   'icon': '',
#   'documentation_links': 'https://go.microsoft.com/fwlink/?LinkId=859748&clcid=0x409'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Azure Bot Service',
#   'link': 'https://azure.microsoft.com/en-us/services/bot-service/',
#   'short_description': 'Intelligent, serverless bot service that scales on demand',
#   'long_description': 'Azure Bot Service is a cost-effective, serverless chatbot service that scales on demand. Focus on building intelligent bots, not how to run and scale them.',
#   'icon': '',
#   'documentation_links': 'http://docs.botframework.com/en-us/azure-bot-service/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Azure Databricks',
#   'link': 'https://azure.microsoft.com/en-us/services/databricks/',
#   'short_description': 'Fast, easy, and collaborative Apache Spark-based analytics platform',
#   'long_description': 'Build and scale your company’s analytics by unifying data science, engineering, and business projects with Microsoft Azure Databricks, an Apache Spark-based service.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/azure-databricks/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Azure Search',
#   'link': 'https://azure.microsoft.com/en-us/services/search/',
#   'short_description': 'Fully-managed search-as-a-service',
#   'long_description': 'Azure Search is a fully managed cloud search service that provides a better user experience for customers. Add Azure Search to your websites to easily optimize search results to meet your business goals.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/search/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Autosuggest',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/autosuggest/',
#   'short_description': 'Give your app intelligent autosuggest options for searches',
#   'long_description': 'Show users intelligent search suggestions with the Bing Autosuggest API from Microsoft Azure. Test out the autocomplete API to see how it works.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/AutoSuggestDocLP'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Custom Search',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/bing-custom-search/',
#   'short_description': 'An easy-to-use, ad-free, commercial-grade search tool that lets you deliver the results you want',
#   'long_description': 'Bing Custom Search is an easy-to-use, ad-free custom search API that lets you deliver the search results you want. Learn more.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/CustomSearchDocLP'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Entity Search',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/bing-entity-search-api/',
#   'short_description': 'Enrich your experiences by identifying and augmenting entity information from the web',
#   'long_description': 'Enrich user experiences by identifying and augmenting entity information with the Bing Entity Search API. Demo the API online to see it in action.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/bing-entities-search/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Image Search',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/bing-image-search-api/',
#   'short_description': 'Search for images and get comprehensive results',
#   'long_description': 'The Bing Image Search API adds a host of image search features to your apps including trending images. Test the image API with our online demo.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/ImageSearchDocLP'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing News Search',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/bing-news-search-api/',
#   'short_description': 'Search for news and get comprehensive results',
#   'long_description': 'Integrate news search functionality into your apps with the Bing News Search API from Microsoft Azure. Try the news API online to see it in action.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/NewSearchDocLP'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Spell Check',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/spell-check/',
#   'short_description': 'Detect and correct spelling mistakes in your app',
#   'long_description': 'Enhance your apps with the Bing Spell Check API from Microsoft Azure. The spell check API corrects spelling mistakes as users are typing.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/SpellCheckDocLP'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Video Search',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/bing-video-search-api/',
#   'short_description': 'Search for videos and get comprehensive results',
#   'long_description': 'Add advanced video search to your apps with the Bing Video Search API from Microsoft Azure. See the powerful video search API in action now.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/VideoSearchDocLP'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Visual Search',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/bing-visual-search/',
#   'short_description': 'Get rich insights to help build compelling image applications on the device of your choice.',
#   'long_description': 'Get rich insights to help build compelling image applications on the device of your choice.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/bingvisualsearchdoclp'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Bing Web Search',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/',
#   'short_description': 'Get enhanced search details from billions of web documents',
#   'long_description': 'Bring the power of intelligent search to your apps with the Bing Web Search API from Microsoft Azure. Try out our online demo to learn more.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/WebSearchDocLP'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Cognitive Services',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/',
#   'short_description': 'Add smart API capabilities to enable contextual interactions',
#   'long_description': 'Microsoft Azure Stack is an extension of Azure—bringing the agility and innovation of cloud computing to your on-premises environment and enabling the only hybrid cloud that allows you to build and deploy hybrid applications anywhere.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Computer Vision',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/computer-vision/',
#   'short_description': 'Distill actionable information from images',
#   'long_description': 'Analyze images and extract the data you need with the Computer Vision API from Microsoft Azure. See the handwriting OCR and analytics features in action now.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/computer-vision/home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Content Moderator',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/content-moderator/',
#   'short_description': 'Automated image, text, and video moderation',
#   'long_description': 'Azure Content Moderator is machine-assisted content filtering software that includes content moderation APIs and a human review tool for images, text, and videos.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/content-moderator/overview'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Custom Speech',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/custom-speech-service/',
#   'short_description': 'Overcome speech recognition barriers like speaking style, background noise, and vocabulary',
#   'long_description': 'Use the Custom Speech Service from Microsoft Azure e to overcome traditional speech recognition software barriers such as vocabulary and background noises.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/custom-speech-service/cognitive-services-custom-speech-home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Custom Vision',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/custom-vision-service/',
#   'short_description': 'Easily customize your own state-of-the-art computer vision models for your unique use case',
#   'long_description': 'The custom vision API from Microsoft Azure learns to recognize specific content in imagery and becomes smarter with training and time. Read on to learn more.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/custom-vision-service/home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Data Science Virtual Machines',
#   'link': 'https://azure.microsoft.com/en-us/services/virtual-machines/data-science-virtual-machines/',
#   'short_description': 'Rich pre-configured environment for AI development',
#   'long_description': 'Comprehensive pre-configured virtual machines for data science modelling, development and deployment.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/dsvmdoc'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Emotion',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/emotion/',
#   'short_description': 'Personalize user experiences with emotion recognition',
#   'long_description': 'Build smarter applications with the Emotion API from Microsoft Azure. Recognize facial emotions in images based on universal facial expressions.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/emotion/home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Face',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/face/',
#   'short_description': 'Detect, identify, analyze, organize, and tag faces in photos',
#   'long_description': 'Build facial recognition software into your applications with the Face API from Microsoft Azure. Detect, identify and verify faces with this powerful API.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/face/overview'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Azure Machine Learning service',
#   'link': 'https://azure.microsoft.com/en-us/services/machine-learning-service/',
#   'short_description': 'Bring AI to everyone with an end-to-end, scalable, trusted platform with experimentation and model management',
#   'long_description': 'Build machine learning applications powered by artificial intelligence (AI) that span from the cloud to the edge. Explore Azure Machine Learning solutions.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/machine-learning/service/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Machine Learning Studio',
#   'link': 'https://azure.microsoft.com/en-us/services/machine-learning-studio/',
#   'short_description': 'Easily build, deploy, and manage predictive analytics solutions',
#   'long_description': 'Create predictive analytics solutions quickly in the cloud with Azure Machine Learning Studio—a collaborative, drag-and-drop tool.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/machine-learning/studio/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Microsoft Genomics',
#   'link': 'https://azure.microsoft.com/en-us/services/genomics/',
#   'short_description': 'Power genome sequencing & research insights',
#   'long_description': 'Power genome sequencing and research insights with Microsoft Genomics—a scalable, secure, compliant Microsoft Azure service for genome alignment and variant calling.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/genomics/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Translator Speech',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/translator-speech-api/',
#   'short_description': 'Easily conduct real-time speech translation with a simple REST API call',
#   'long_description': 'The Translator Speech API from Microsoft Azure allows you to easily include real-time speech translation in your apps. Learn more about the value of this API.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/translator-speech/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Language Understanding',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/language-understanding-intelligent-service/',
#   'short_description': 'Teach your apps to understand commands from your users',
#   'long_description': 'The Language Understanding (LUIS), allows your applications to communicate with users in a natural way. See LUIS in action to learn more.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/luis/home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Linguistic Analysis',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/linguistic-analysis-api/',
#   'short_description': 'Simplify complex language concepts and parse text with the Linguistic Analysis API',
#   'long_description': 'The Linguistics Analysis API from Microsoft Azure simplifies language with tools like part-of-speech tagging. Learn more by trying out the online demo.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/linguisticanalysisapi/home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'QnA Maker',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/qna-maker/',
#   'short_description': 'Distill information into conversational, easy-to-navigate answers',
#   'long_description': 'Create a knowledge base of questions and answers with the QnA Maker API from Microsoft Azure. Test the online demo to see how the FAQ Service works.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/qnamaker/home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Speaker Recognition',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/speaker-recognition/',
#   'short_description': 'Use speech to identify and verify individual speakers',
#   'long_description': 'Use speech for voice authentication and authorization with the Speaker Recognition API from Azure. Try the demo online to see how it works.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/speaker-recognition/home'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Speech Translation',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/speech-translation/',
#   'short_description': 'Easily integrate real-time speech translation to your app',
#   'long_description': 'The Speech Translation from Microsoft Azure allows you to easily include real-time speech translation in your apps.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/speech-service/speech-translation'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Speech to Text',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/speech-to-text/',
#   'short_description': 'The Speech to Text API is part of Azure Cognitive Services Speech Services',
#   'long_description': 'Build smarter apps. Speech to Text transcription converts audio to text for natural responsiveness. Explore scenarios for your business.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/speech-service/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Text Analytics',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/text-analytics/',
#   'short_description': 'Easily evaluate sentiment and topics to understand what users want',
#   'long_description': 'Turn unstructured text into meaningful insights with the Azure Text Analytics API. Get sentiment analysis, key phrase extraction, and language and entity detection.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/overview'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Text to Speech',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/text-to-speech/',
#   'short_description': 'Convert text to speech to create more natural, accessible interfaces',
#   'long_description': 'Improve user experience and accessibility for your apps by converting text to speech. Text to Speech gives you speech synthesis in multiple languages and the ability to build intelligent kiosks.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/speech-service/text-to-speech'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Translator Text',
#   'link': 'https://azure.microsoft.com/en-us/services/cognitive-services/translator-text-api/',
#   'short_description': 'Easily conduct machine translation with a simple REST API call',
#   'long_description': 'The Translator Text API is a cloud-based machine translation service that extends the reach of apps. With over 60 supported languages, learn more about this API.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/translator/translator-info-overview/'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Video Indexer',
#   'link': 'https://azure.microsoft.com/en-us/services/media-services/video-indexer/',
#   'short_description': 'Unlock video insights',
#   'long_description': 'Quickly extract insights from videos using the artificial intelligence of Video Indexer from Azure. Detect words, identify faces, and build workflows.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cognitive-services/video-indexer/video-indexer-overview'},
#  {'category_id': 'ai-machine-learning',
#   'category_name': 'AI + Machine Learning',
#   'category_link': 'https://azure.microsoft.com/en-us/overview/ai-platform/',
#   'name': 'Azure Kinect DK',
#   'link': 'https://azure.microsoft.com/en-us/services/kinect-dk/',
#   'short_description': 'Build computer vision and speech models using a developer kit with advanced AI sensors',
#   'long_description': 'Developers: Build advanced computer vision and speech models with a 1-MP depth sensor,\r\n12-MP RGB camera, and 7-mic audio array in a single device.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/kinectdocs'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Azure Databricks',
#   'link': 'https://azure.microsoft.com/en-us/services/databricks/',
#   'short_description': 'Fast, easy, and collaborative Apache Spark-based analytics platform',
#   'long_description': 'Build and scale your company’s analytics by unifying data science, engineering, and business projects with Microsoft Azure Databricks, an Apache Spark-based service.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/azure-databricks/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Azure Stream Analytics',
#   'link': 'https://azure.microsoft.com/en-us/services/stream-analytics/',
#   'short_description': 'Real-time data stream processing from millions of IoT devices',
#   'long_description': 'Learn about Azure Stream Analytics, an event data processing service providing real-time analytics and insights from apps, devices, sensors, and more.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/stream-analytics/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'SQL Data Warehouse',
#   'link': 'https://azure.microsoft.com/en-us/services/sql-data-warehouse/',
#   'short_description': 'Elastic data warehouse as a service with enterprise-class features',
#   'long_description': 'Get started with Azure SQL Data Warehouse for an enterprise-class SQL Server experience. Cloud data warehouses offer flexibility, scalability, and big data insights.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/sql-data-warehouse/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'HDInsight',
#   'link': 'https://azure.microsoft.com/en-us/services/hdinsight/',
#   'short_description': 'Provision cloud Hadoop, Spark, R Server, HBase, and Storm clusters',
#   'long_description': 'Learn about HDInsight, an open source analytics service that runs Hadoop, Spark, Kafka, and more. Integrate HDInsight with other Azure services for superior analytics.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/hdinsight/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Data Factory',
#   'link': 'https://azure.microsoft.com/en-us/services/data-factory/',
#   'short_description': 'Hybrid data integration at enterprise scale, made easy',
#   'long_description': 'Learn more about Azure Data Factory, the easiest cloud-based hybrid data integration solution at an enterprise scale. Build data factories without the need to code.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/data-factory/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Data Lake Analytics',
#   'link': 'https://azure.microsoft.com/en-us/services/data-lake-analytics/',
#   'short_description': 'Distributed analytics service that makes big data easy',
#   'long_description': 'Big data analytics made easy',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/data-lake-analytics/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Event Hubs',
#   'link': 'https://azure.microsoft.com/en-us/services/event-hubs/',
#   'short_description': 'Receive telemetry from millions of devices',
#   'long_description': 'Learn about Azure Event Hubs, a managed service that can ingest and process massive data streams from websites, apps, or devices.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/event-hubs/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Power BI Embedded',
#   'link': 'https://azure.microsoft.com/en-us/services/power-bi-embedded/',
#   'short_description': 'Embed fully interactive, stunning data visualizations in your applications',
#   'long_description': 'Microsoft Power BI Embedded allows you to embed stunning, fully-interactive reports into your apps without building controls from the ground up.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/power-bi-embedded/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Azure Analysis Services',
#   'link': 'https://azure.microsoft.com/en-us/services/analysis-services/',
#   'short_description': 'Enterprise-grade analytics engine as a service',
#   'long_description': 'Built on the proven analytical engine in Microsoft SQL Server Analysis Services, Azure Analysis Services delivers enterprise-grade data modeling in the cloud.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/analysis-services/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Data Catalog',
#   'link': 'https://azure.microsoft.com/en-us/services/data-catalog/',
#   'short_description': 'Get more value from your enterprise data assets',
#   'long_description': 'Get more value from your enterprise data assets with Azure Data Catalog. Spend less time looking for data and more time getting value from it. Get started today.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/data-catalog/'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Azure Data Lake Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/data-lake-storage/',
#   'short_description': 'Massively scalable, secure data lake functionality built on Azure Blob Storage',
#   'long_description': 'Azure Data Lake Storage Gen2 is highly scalable and secure storage for big data analytics. Maximize costs and efficiency through full integrations with other Azure products.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/data-lake-storage-community'},
#  {'category_id': 'analytics',
#   'category_name': 'Analytics',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/analytics/',
#   'name': 'Azure Data Explorer',
#   'link': 'https://azure.microsoft.com/en-us/services/data-explorer/',
#   'short_description': 'Fast and highly scalable data exploration service',
#   'long_description': 'Quickly query and gain insights from large volumes of log and telemetry data using Azure Data Explorer, a powerful data exploration and analytics service.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/data-explorer/'},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/compute/',
#   'name': 'Virtual Machines',
#   'link': 'https://azure.microsoft.com/en-us/services/virtual-machines/',
#   'short_description': 'Provision Windows and Linux virtual machines in seconds',
#   'long_description': 'Quickly create a scalable Linux or Windows Server virtual machine with Azure Virtual Machines. Deploy open-source virtual machines on-premises or in the cloud.',
#   'icon': '',
#   'documentation_links': ['https://docs.microsoft.com/en-us/azure/virtual-machines/linux/',
#    'https://docs.microsoft.com/en-us/azure/virtual-machines/windows/']},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/compute/',
#   'name': 'Virtual Machine Scale Sets',
#   'link': 'https://azure.microsoft.com/en-us/services/virtual-machine-scale-sets/',
#   'short_description': 'Manage and scale up to thousands of Linux and Windows virtual machines',
#   'long_description': 'Make autoscaling your virtual machines easier with Azure and run hundreds of identical virtual machines in minutes.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/virtual-machine-scale-sets/'},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/compute/',
#   'name': 'Azure Kubernetes Service (AKS)',
#   'link': 'https://azure.microsoft.com/en-us/services/kubernetes-service/',
#   'short_description': 'Simplify the deployment, management, and operations of Kubernetes',
#   'long_description': 'Easily manage Kubernetes with Azure Kubernetes Service (AKS), formerly known as Azure Container Service. Use a Kubernetes service with added security and fast deployment.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/aks/'},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/compute/',
#   'name': 'Azure Functions',
#   'link': 'https://azure.microsoft.com/en-us/services/functions/',
#   'short_description': 'Process events with serverless code',
#   'long_description': 'Build apps faster with a serverless architecture. Azure Functions delivers an event-driven serverless compute experience with scale on demand.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/azure-functions/'},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/compute/',
#   'name': 'Service Fabric',
#   'link': 'https://azure.microsoft.com/en-us/services/service-fabric/',
#   'short_description': 'Develop microservices and orchestrate containers on Windows or Linux',
#   'long_description': 'Rapidly develop and update microservice-based applications with Azure Service Fabric that lets developers build features without additional infrastructure coding.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/service-fabric/'},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/compute/',
#   'name': 'App Service',
# ...
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/security/',
#   'name': 'VPN Gateway',
#   'link': 'https://azure.microsoft.com/en-us/services/vpn-gateway/',
#   'short_description': 'Establish secure, cross-premises connectivity',
#   'long_description': 'Connecting your infrastructure to the cloud',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/vpn-gateway/'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/security/',
#   'name': 'Application Gateway',
#   'link': 'https://azure.microsoft.com/en-us/services/application-gateway/',
#   'short_description': 'Build secure, scalable, and highly available web front ends in Azure',
#   'long_description': 'Azure Application Gateway provides application-level routing and is a load balancing solution that lets you build a scalable and highly-available web frontend in Azure.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/application-gateway/'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/security/',
#   'name': 'Azure DDoS Protection',
#   'link': 'https://azure.microsoft.com/en-us/services/ddos-protection/',
#   'short_description': 'Protect your applications from Distributed Denial of Service (DDoS) attacks',
#   'long_description': 'Defend against Distributed Denial of Service (DDoS) attacks on your applications and network with integrated DDoS protection and mitigation services from Azure.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/ddosprotectiondocs'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/security/',
#   'name': 'Azure Sentinel',
#   'link': 'https://azure.microsoft.com/en-us/services/azure-sentinel/',
#   'short_description': 'Intelligent security analytics for your entire enterprise',
#   'long_description': 'Microsoft Azure Sentinel is a cloud-native SIEM with advanced AI and security analytics to help you detect, prevent, and respond to threats across your enterprise.',
#   'icon': '',
#   'documentation_links': '/en-us/pricing/details/azure-sentinel/'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/',
#   'short_description': 'Durable, highly available, and massively scalable cloud storage',
#   'long_description': 'Learn about Azure Storage, a durable, highly available, massively scalable cloud storage solution. ',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/storage/'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Azure Backup',
#   'link': 'https://azure.microsoft.com/en-us/services/backup/',
#   'short_description': 'Simplify data protection and protect against ransomware',
#   'long_description': 'Azure Backup is a reliable and cost-effective online backup system. Use this Azure cloud backup as a service for backing up data online.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/backup/'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'StorSimple',
#   'link': 'https://azure.microsoft.com/en-us/services/storsimple/',
#   'short_description': 'Lower costs with an enterprise hybrid cloud storage solution',
#   'long_description': 'Learn about Azure StorSimple, a hybrid online cloud storage service for enterprises designed to reduce costs and improve data protection. ',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/storsimple/'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Azure Data Lake Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/data-lake-storage/',
#   'short_description': 'Massively scalable, secure data lake functionality built on Azure Blob Storage',
#   'long_description': 'Azure Data Lake Storage Gen2 is highly scalable and secure storage for big data analytics. Maximize costs and efficiency through full integrations with other Azure products.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/data-lake-storage-community'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Blob Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/blobs/',
#   'short_description': 'REST-based object storage for unstructured data',
#   'long_description': 'Use Azure Blob Storage to store all kinds of files. Azure hot, cool, and archive storage is reliable cloud object storage for unstructured data.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/storage/blobs/storage-dotnet-how-to-use-blobs'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Disk Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/disks/',
#   'short_description': 'Persistent, secured disk options supporting virtual machines',
#   'long_description': 'Explore SSD and HDD managed disks available to meet your company demands. Azure Disks are designed for 99.999% availability.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/virtual-machines/windows/about-disks-and-vhds'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Managed Disks',
#   'link': 'https://azure.microsoft.com/en-us/services/managed-disks/',
#   'short_description': 'Persistent, secured disk storage for Azure virtual machines',
#   'long_description': 'Explore SSD and HDD managed disks available to meet your company demands. Azure Disks are designed for 99.999% availability.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/virtual-machines/windows/about-disks-and-vhds'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Queue Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/queues/',
#   'short_description': 'Effectively scale apps according to traffic',
#   'long_description': 'Get started today with Azure Premium Storage for low latency and high throughput storage suitable for I/O intensive applications.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/storage/queues/storage-dotnet-how-to-use-queues'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'File Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/files/',
#   'short_description': 'File shares that use the standard SMB 3.0 protocol',
#   'long_description': 'Try Azure File Storage for managed file shares that use standard SMB 3.0 protocol. Share data with on-premises and cloud servers, integrate with apps, and more.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/storage/files/storage-files-introduction'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Data Box',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/databox/',
#   'short_description': 'Secure, ruggedized appliance for Azure data transfer',
#   'long_description': 'Use Azure Data Box products to transfer large amounts of data into Azure Storage from the edge. Learn more about all Data Box products.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/databoxdocshub'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Avere vFXT for Azure',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/avere-vfxt/',
#   'short_description': 'Run high-performance, file-based workloads in the cloud',
#   'long_description': 'Avere vFXT for Azure is a scalable file system that can process very large datasets flexibly and affordably. Manage your hybrid HPC workloads with Azure.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/avere-vfxt'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Archive Storage',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/archive/',
#   'short_description': 'Industry leading price point for storing rarely accessed data',
#   'long_description': 'Low cost, secure cloud storage for rarely accessed data. Exponential data growth doesn’t have to mean exponential costs for data storage and management. Azure Archive Storage is designed to provide organizations with a low cost means of delivering durable, highly available, secure cloud storage for rarely accessed data with flexible latency requirements.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/storage/blobs/storage-blob-storage-tiers'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/storage/',
#   'name': 'Azure NetApp Files',
#   'link': 'https://azure.microsoft.com/en-us/services/storage/netapp/',
#   'short_description': 'Powerful, hybrid network file system (NFS) file shares',
#   'long_description': 'Discover Azure Netapp Files—the hybrid network file system (NFS) that provides a sophisticated enterprise-grade experience with the security, compliance, and power of NetApp and Azure.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/azure-netapp-files'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'App Service',
#   'link': 'https://azure.microsoft.com/en-us/services/app-service/',
#   'short_description': 'Quickly create powerful cloud apps for web and mobile',
#   'long_description': 'Use Azure App Service to create powerful cloud apps for web and mobile clients running on any platform or device faster than ever before.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/app-service/'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'Content Delivery Network',
#   'link': 'https://azure.microsoft.com/en-us/services/cdn/',
#   'short_description': 'Ensure secure, reliable content delivery with broad global reach',
#   'long_description': 'Learn about Azure Content Delivery Network, a secure and reliable global content delivery and acceleration solution.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/cdn/'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'Azure Search',
#   'link': 'https://azure.microsoft.com/en-us/services/search/',
#   'short_description': 'Fully-managed search-as-a-service',
#   'long_description': 'Azure Search is a fully managed cloud search service that provides a better user experience for customers. Add Azure Search to your websites to easily optimize search results to meet your business goals.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/search/'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'Notification Hubs',
#   'link': 'https://azure.microsoft.com/en-us/services/notification-hubs/',
#   'short_description': 'Send push notifications to any platform from any back end',
#   'long_description': 'Learn about Azure Notification Hubs. Send push notifications to iOS, Android, Windows, or Kindle from any backend. Easier mobile app development.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/notification-hubs/'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'API Management',
#   'link': 'https://azure.microsoft.com/en-us/services/api-management/',
#   'short_description': 'Publish APIs to developers, partners, and employees securely and at scale',
#   'long_description': 'Azure API Management offers a scalable API gateway for securing, publishing, and analyzing APIs and microservices to internal and external consumers.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/api-management/'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'Web Apps',
#   'link': 'https://azure.microsoft.com/en-us/services/app-service/web/',
#   'short_description': 'Quickly create and deploy mission critical web apps at scale',
#   'long_description': 'Create and deploy mission critical Web apps that scale with your business',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/app-service/app-service-web-overview'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'Mobile Apps',
#   'link': 'https://azure.microsoft.com/en-us/services/app-service/mobile/',
#   'short_description': 'Build and host the backend for any mobile app',
#   'long_description': "Build engaging cross-platform and native apps for iOS, Android, Windows or Mac with Azure's Mobile App Service.",
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/app-service-mobile'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'API Apps',
#   'link': 'https://azure.microsoft.com/en-us/services/app-service/api/',
#   'short_description': 'Easily build and consume Cloud APIs',
#   'long_description': 'Azure API Apps give you the tools to develop, host, secure, and share REST APIs in your organization or with the world.',
#   'icon': '',
#   'documentation_links': 'https://docs.microsoft.com/en-us/azure/app-service/'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'Web App for Containers',
#   'link': 'https://azure.microsoft.com/en-us/services/app-service/containers/',
#   'short_description': 'Easily deploy and run containerized web apps that scale with your business',
#   'long_description': 'Bring your own containers and deploy to App Service as a web app running on Linux in seconds using Web App for Containers feature of Azure App Service.',
#   'icon': '',
#   'documentation_links': 'https://aka.ms/AppServiceLinuxDocs'},
#  {'category_id': 'web',
#   'category_name': 'Web',
#   'category_link': 'https://azure.microsoft.com/en-us/product-categories/web/',
#   'name': 'Azure SignalR Service',
#   'link': 'https://azure.microsoft.com/en-us/services/signalr-service/',
#   'short_description': 'Add real-time web functionalities easily',
#   'long_description': 'Azure SignalR Service makes it easy to build and manage real-time web applications.',
#   'icon': '',
#   'documentation_links': 'https://go.microsoft.com/fwlink/?LinkId=873038&clcid=0x409'}]

# %%
soup = BeautifulSoup(requests.get('https://azure.microsoft.com/en-us/services/machine-learning-service/').text, 'html.parser')

# %%
soup.find('main', {'id': 'main'}).find(text='Overview').parent.parent.parent
# Out:
# <div class="row">
# <div class="column medium-offset-2 medium-10">
# <h2>Overview</h2>
# </div>
# </div>
