# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = 'https://www.digitalocean.com'

# %%
base_soup = BeautifulSoup(requests.get(f'{base_url}/products').text, 'html.parser')

# %%
digiocean_services = []
for cat_soup in base_soup.find_all('section', {'class': 'InPageNav-anchor'}):
    cat_id = cat_soup['id']
    cat_name = cat_soup.find('h3').text.strip()
    cat_desc = cat_soup.find('p').text.strip()
    for svc_soup in cat_soup.find_all('a', {'class': 'www-Card'}):
        name = svc_soup.find('h4').text.strip()
        link = svc_soup['href'].strip()
        url = f'{base_url}{link}'
        
        short_desc = svc_soup.find('p').text.strip()
        icon_src = svc_soup.find('img')['src']
        icon_url = f'{base_url}{icon_src}'
        digiocean_services.append({
            'category_id': cat_id,
            'category_name': cat_name,
            'category_description': cat_desc,
            'name': name,
            'link': url,
            'short_description': short_desc,
            'long_description': '',
            'icon': icon_url
        })
digiocean_services
# Out:
# [{'category_id': 'anchor--compute',
#   'category_name': 'Compute',
#   'category_description': 'Build and release faster with scalable compute products in the cloud. DigitalOcean provides flexible server configurations sized for any application, industry leading price to performance, and predictable pricing that is the same across regions and usage volumes.',
#   'name': 'Standard Droplets',
#   'link': 'https://www.digitalocean.com/products/droplets/',
#   'short_description': 'Deploy your application with all purpose compute servers that have a balance of CPU, memory, local SSD storage, and bandwidth at a predictable and affordable price.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/droplets-icon-17d76fd6.svg'},
#  {'category_id': 'anchor--compute',
#   'category_name': 'Compute',
#   'category_description': 'Build and release faster with scalable compute products in the cloud. DigitalOcean provides flexible server configurations sized for any application, industry leading price to performance, and predictable pricing that is the same across regions and usage volumes.',
#   'name': 'General Purpose Droplets',
#   'link': 'https://www.digitalocean.com/products/droplets/',
#   'short_description': 'Run a wide range of production workloads with a healthy balance of memory and dedicated compute hyper-threads from best-in-class Intel processors.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/droplets-icon-17d76fd6.svg'},
#  {'category_id': 'anchor--compute',
#   'category_name': 'Compute',
#   'category_description': 'Build and release faster with scalable compute products in the cloud. DigitalOcean provides flexible server configurations sized for any application, industry leading price to performance, and predictable pricing that is the same across regions and usage volumes.',
#   'name': 'CPU-Optimized Droplets',
#   'link': 'https://www.digitalocean.com/products/droplets/',
#   'short_description': 'Run computationally intensive workloads quickly and with dedicated, powerful CPU resources that can be deployed in seconds.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/optimized-droplet-icon-b32397ee.svg'},
#  {'category_id': 'anchor--compute',
#   'category_name': 'Compute',
#   'category_description': 'Build and release faster with scalable compute products in the cloud. DigitalOcean provides flexible server configurations sized for any application, industry leading price to performance, and predictable pricing that is the same across regions and usage volumes.',
#   'name': 'Kubernetes',
#   'link': 'https://www.digitalocean.com/products/kubernetes/',
#   'short_description': 'Gain uptime, scalability, and portability for your cloud native applications with a managed Kubernetes cluster designed for ease of use and cost effectiveness.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/kubernetes-icon-fc0f45ba.svg'},
#  {'category_id': 'anchor--storage',
#   'category_name': 'Storage',
#   'category_description': 'Store and quickly access any amount of data reliably in the cloud. DigitalOcean offers several kinds of storage depending on your needs.',
#   'name': 'Spaces Object Storage',
#   'link': 'https://www.digitalocean.com/products/spaces/',
#   'short_description': 'Store and scale vast amounts of data without worrying about compute server storage limits. Manage your data with S3-compatible tools.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/spaces-icon-12c1c6e7.svg'},
#  {'category_id': 'anchor--storage',
#   'category_name': 'Storage',
#   'category_description': 'Store and quickly access any amount of data reliably in the cloud. DigitalOcean offers several kinds of storage depending on your needs.',
#   'name': 'Spaces Content Delivery Network',
#   'link': 'https://www.digitalocean.com/products/spaces/',
#   'short_description': 'Quickly deliver data from Spaces with a built-in content delivery network that is close to end users.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/spaces-cdn-icon-2cb3e5d2.svg'},
#  {'category_id': 'anchor--storage',
#   'category_name': 'Storage',
#   'category_description': 'Store and quickly access any amount of data reliably in the cloud. DigitalOcean offers several kinds of storage depending on your needs.',
#   'name': 'Volumes Block Storage',
#   'link': 'https://www.digitalocean.com/products/block-storage/',
#   'short_description': 'Add storage to your compute servers as needed.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/blockstorage-26d68489.svg'},
#  {'category_id': 'anchor--networking',
#   'category_name': 'Networking',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'Cloud Firewalls',
#   'link': 'https://www.digitalocean.com/products/cloud-firewalls/',
#   'short_description': 'Protect your applications by filtering out unwanted traffic. Filtering occurs upstream and in front of your server infrastructure.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/cloud-firewalls-icon-3e57adb5.svg'},
#  {'category_id': 'anchor--networking',
#   'category_name': 'Networking',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'Load Balancers',
#   'link': 'https://www.digitalocean.com/products/load-balancer/',
#   'short_description': 'Scale your applications more easily with a highly available load balancing service that directs users to available resources.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/load-balancers-icon-4cf52fc5.svg'},
#  {'category_id': 'anchor--networking',
#   'category_name': 'Networking',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'Virtual Private Cloud (VPC)',
#   'link': 'https://www.digitalocean.com/docs/networking/private-networking/',
#   'short_description': 'Improve your application security with your own private network, which restricts traffic to resources provisioned on your same account.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/virtual-private-cloud-icon-7af24d1a.svg'},
#  {'category_id': 'anchor--networking',
#   'category_name': 'Networking',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'Floating IPs',
#   'link': 'https://www.digitalocean.com/docs/networking/floating-ips/',
#   'short_description': 'Increase availability by easily switching incoming traffic across your server infrastructure.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/floating-ips-icon-07964ea6.svg'},
#  {'category_id': 'anchor--networking',
#   'category_name': 'Networking',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'DNS',
#   'link': 'https://www.digitalocean.com/docs/networking/dns/',
#   'short_description': 'Reliable resolutions with a scalable domain name system (DNS) service.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/domain-name-system-icon-d242a77a.svg'},
#  {'category_id': 'anchor--databases',
#   'category_name': 'Databases',
#   'category_description': 'Combine the power of our core VM platform with a fully managed PostgreSQL database engine to give your application the performance it needsâ\x80\x94without the operational demands that come with building and running your own database server.',
#   'name': 'Managed Postgres',
#   'link': 'https://www.digitalocean.com/products/managed-databases/',
#   'short_description': 'Combine the power of our core VM platform with a fully managed PostgreSQL database engine to give your application the performance it needsâ\x80\x94without the operational demands that come with building and running your own database server.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/managed-postgres-icon-0328a19b.svg'},
#  {'category_id': 'anchor--developer-tools',
#   'category_name': 'Developer Tools',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'DigitalOcean API',
#   'link': 'https://www.digitalocean.comhttps://developers.digitalocean.com/documentation/v2/',
#   'short_description': 'Programmatically manage your DigitalOcean infrastructure with our RESTful API.  Or use our collection of libraries to access our API in your preferred programming language.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/api-icon-4af57780.svg'},
#  {'category_id': 'anchor--developer-tools',
#   'category_name': 'Developer Tools',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'DigitalOcean CLI',
#   'link': 'https://www.digitalocean.com/products/tools-and-integrations/',
#   'short_description': 'Manage your DigitalOcean infrastructure through your terminal with our open source Command Line Interface (CLI).',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/cli-icon-688fef48.svg'},
#  {'category_id': 'anchor--developer-tools',
#   'category_name': 'Developer Tools',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'Monitoring',
#   'link': 'https://www.digitalocean.com/products/monitoring/',
#   'short_description': 'Monitor application and infrastructure resource usage with built in monitoring and alerting.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/monitoring-icon-7203c469.svg'},
#  {'category_id': 'anchor--developer-tools',
#   'category_name': 'Developer Tools',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'DigitalOcean Teams',
#   'link': 'https://www.digitalocean.com/products/teams/',
#   'short_description': 'Collaborate with others to manage and scale infrastructure without sharing credentials.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/teams-icon-48b2de3d.svg'},
#  {'category_id': 'anchor--developer-tools',
#   'category_name': 'Developer Tools',
#   'category_description': 'Secure and control the traffic to your applications with your own private network, traffic filtering, and load balancing.',
#   'name': 'DigitalOcean Marketplace',
#   'link': 'https://www.digitalocean.com/products/marketplace/',
#   'short_description': 'Add new functionality to your applications through open source and commercial software.',
#   'long_description': '',
#   'icon': 'https://www.digitalocean.com/assets/media/products/marketplace-icon-9e4f916b.svg'}]
