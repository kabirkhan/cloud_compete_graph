# %%
import requests
from bs4 import BeautifulSoup

# %%
paas_url = 'https://www.oracle.com/cloud/platform.html'
iaas_url = 'https://www.oracle.com/cloud/infrastructure.html'

# %%
def get_services(base_url):
    print(base_url)
    soup = BeautifulSoup(requests.get(base_url).text, 'html.parser')
    cat_soups = soup.find('section', {'class': 'cw60'}).find_all('div', {'class': 'cw60w2'})

    services = []
    for c_soup in cat_soups:
        cat_id = c_soup.find('a')['href'][1:]
        h6 = c_soup.find('h6', {'class': 'beforeblue'})
        cat_name = h6.text
        print(cat_name)

        for s_soup in c_soup.find_all('div', {'class': 'cw60w4'}):
            name = s_soup.find('a').text
            link = s_soup.find('a')['href']
            short_desc = s_soup.find('p').text
            if link.startswith('/'):
                continue
            page_soup = BeautifulSoup(requests.get(link).text, 'html.parser')
            try:
                long_desc = page_soup.find('h5', {'black-center'}).text
            except:
                try:
                    long_desc = page_soup.find('h6', {'class': 'grey2'}).text
                except:
                    long_desc = ''
            icon = page_soup.find('div', {'class': 'service-banner-icon'})
            try:
                icon_url =  f"https://cloud.oracle.com{icon.find('img')['src']}" if icon else ''
            except:
                icon_uri = ''

            services.append({
                'category_id': cat_id,
                'category_name': cat_name,
                'name': name,
                'short_description': short_desc,
                'long_description': long_desc,
                'link': link,
                'icon': icon_url
            })
    return services
services = get_services(iaas_url) + get_services(paas_url)
services
# Out:
# https://www.oracle.com/cloud/infrastructure.html
# Compute
# Storage
# Networking
# FastConnect
# Containers
# Security
# Edge Services
# Ravello Service
# https://www.oracle.com/cloud/platform.html
# Application Development
# Business Analytics
# Cloud at Customer
# Content and Experience Management
# Data Integration
# Data Management
# Enterprise Integration
# Security
# Systems Management
# [{'category_id': 'compute',
#   'category_name': 'Compute',
#   'name': 'Bare Metal Compute',
#   'short_description': 'Oracle Cloud Infrastructure Bare Metal compute instances provide on-demand access to dedicated physical servers offering high, predictable performance for the most demanding workloads.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/compute/bare-metal/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BareMetalCompute_w_72%402x.png'},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'name': 'GPU-based Virtual Machines and Bare Metal',
#   'short_description': 'NVIDIA-based offerings provide a range of options for graphics intensive workloads, while also providing the high performance demanded by artificial Intelligence and machine- learning algorithms.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/compute/gpu/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BareMetalCompute_w_72%402x.png'},
#  {'category_id': 'compute',
#   'category_name': 'Compute',
#   'name': 'Virtual Machines',
#   'short_description': 'Oracle Cloud Infrastructure Virtual Machines (VMs) VMs are ideal for running applications that do not require the performance of a dedicated bare metal server.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/compute/virtual-machine/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BareMetalCompute_w_72%402x.png'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'name': 'Block Volume',
#   'short_description': 'Oracle Cloud Infrastructure Block Volume Storage service allows businesses to dynamically provision and manage block storage volumes. All flash storage provides extremely high performance and Oracle does not charge for IOPS.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/storage/block-volume/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSBlockVolume_w_72%402x.png'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'name': 'File Storage',
#   'short_description': 'Oracle Cloud Infrastructure File Storage is an enterprise-grade, cloud file storage service offering massive scalability, high availability, and extensive durability.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/storage/file-storage/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSBlockVolume_w_72%402x.png'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'name': 'Object Storage',
#   'short_description': 'Oracle Cloud Infrastructure Object Storage provides reliable, durable, and highly available object storage.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/storage/object-storage/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSBlockVolume_w_72%402x.png'},
#  {'category_id': 'storage',
#   'category_name': 'Storage',
#   'name': 'Archive Storage',
#   'short_description': 'Oracle Cloud Infrastructure Archive Storage is used for retaining data that is accessed infrequently and requires long retention periods. All data at rest is encrypted.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/storage/archive-storage/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSBlockVolume_w_72%402x.png'},
#  {'category_id': 'networking',
#   'category_name': 'Networking',
#   'name': 'Networking',
#   'short_description': 'Oracle Cloud Infrastructure Networking allows business to extend their IT infrastructure with highly customizable virtual cloud networks (VCN), and connectivity services connecting on-premises data centers to Oracle Cloud Infrastructure.',
#   'long_description': 'Extend your IT infrastructure with highly customizable Virtual Cloud Networks (VCN) and connectivity services offering predictable and consistent performance, isolation, and availability.',
#   'link': 'https://cloud.oracle.com/networking',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSVCN_w_72%402x.png'},
#  {'category_id': 'networking',
#   'category_name': 'Networking',
#   'name': 'Load Balancing',
#   'short_description': 'Oracle Cloud Infrastructure Load Balancing offers options to distribute workload processes across multiple resources in multitier and highly distributed application architectures to ensure availability.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/load-balancing ',
#   'icon': ''},
#  {'category_id': 'fastconnect',
#   'category_name': 'FastConnect',
#   'name': 'FastConnect',
#   'short_description': 'Oracle Cloud Infrastructure FastConnect service enables businesses to extend their IT infrastructure with dedicated connectivity to Oracle Cloud Infrastructure resources. As an alternative to using the public internet, FastConnect offers predictable and consistent performance, and there are no charges for data egress.',
#   'long_description': 'Extend your IT infrastructure with connectivity services offering predictable and consistent performance, isolation, and availability.',
#   'link': 'https://cloud.oracle.com/en_US/fastconnect',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/FastConnect_w_72%402x.png'},
#  {'category_id': 'containers',
#   'category_name': 'Containers',
#   'name': 'Containers',
#   'short_description': 'Oracle Cloud Infrastructure offers a managed Kubernetes service for creating and managing clusters, and a private registry for storing and sharing container images.',
#   'long_description': 'Open, enterprise-grade, container-native platform, fully integrated with Oracle Cloud Infrastructure.',
#   'link': 'https://cloud.oracle.com/containers',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/OBMC_Container_white-144x144.png'},
#  {'category_id': 'containers',
#   'category_name': 'Containers',
#   'name': 'Container Engine for Kubernetes',
#   'short_description': 'Get the latest Kubernetes updates and keep pace and compatibility with the CNCF ecosystem without the management and administrative overhead, all integrated with your Oracle Cloud Infrastructure tenancy.',
#   'long_description': 'A developer friendly, container-native, and enterprise-ready managed Kubernetes service for running highly available clusters with the control, security, and predictable performance of Oracle’s Cloud Infrastructure.',
#   'link': 'https://cloud.oracle.com/containers/clusters/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/OBMC_Container_white-144x144.png'},
#  {'category_id': 'containers',
#   'category_name': 'Containers',
#   'name': 'Registry',
#   'short_description': 'A highly available private container registry service for storing and sharing container images within the same regions as the deployments. Push and pull images with the Docker CLI, or directly into Kubernetes deployments.',
#   'long_description': 'A highly available private container registry service for storing and sharing container images within the same regions as the deployments.',
#   'link': 'https://cloud.oracle.com/containers/container-registry/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/OBMC_Container_white-144x144.png'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'name': 'Security',
#   'short_description': 'Security is a core design principle within Oracle Cloud Infrastructure. Oracle offers core-to-edge security, including superior customer isolation, customer data protection, protection against internet threats, and highly automated threat remediation. Within our infrastructure, we isolate compute and network resources, ensuring that no customer can see any other customer’s data or traffic.',
#   'long_description': 'The Oracle Identity and Access Management (IAM) service lets you control who has access to cloud resources, what type of access they have, and to which specific resources. You can manage complex organizations and rules with logical groups of users and resources, and easy-to-define policies. With IAM, Oracle Cloud Infrastructure users can leverage a single model for authentication and authorization at no additional cost.',
#   'link': 'https://cloud.oracle.com/en_US/cloud-security/identity/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMC_Governance_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'name': 'Cloud Access Security Broker (CASB)',
#   'short_description': 'Protect your entire IaaS, SaaS, and PaaS cloud footprint. Oracle CASB Cloud Service is a multimode cloud-access security broker that provides advanced threat analytics using user-behavior analytics (UBA) and third-party feeds, configuration seeding, monitoring and alerts, and shadow IT discovery.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/cloud-security/casb/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMC_Governance_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'name': 'Key Management Service (KMS)',
#   'short_description': 'Use KMS services to define key usage and management policies and grant Oracle IAM users, groups, or services the rights to use, manage, or associate your keys with resources. Our Key Management service stores keys in isolated partitions inside FIPS 140-2, Security Level 3 certified hardware security modules (HSMs), replicated multiple times within a region to ensure the durability and availability of the keys.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/cloud-security/kms/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMC_Governance_w_72.png'},
#  {'category_id': 'edge-services',
#   'category_name': 'Edge Services',
#   'name': 'Domain Name System (DNS)',
#   'short_description': 'Use managed DNS services for network resiliency and to optimize global web application traffic based on industry-leading Dyn offerings. DNS performance matters. For modern sites and applications, DNS resolution can account for up to 30 percent of site-load time. Dyn is consistently at the top of the league table for DNS performance. We respond to DNS queries in less than 30 milliseconds worldwide, and propagate DNS records across the globe in under a minute.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/edge/dns/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/EdgeServices.png'},
#  {'category_id': 'edge-services',
#   'category_name': 'Edge Services',
#   'name': 'Edge Services',
#   'short_description': "Oracle's edge services span from industry-leading DNS services to no-cost DNS-based DDOS protection. Additional services include a web application firewall and an SMTP email delivery service.",
#   'long_description': 'Protect cloud-hosted resources and deliver consistent, industry-leading performance and positive user experiences. Stay ahead of issues that can negatively impact business processes.',
#   'link': 'https://cloud.oracle.com/en_US/edge',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/EdgeServices.png'},
#  {'category_id': 'edge-services',
#   'category_name': 'Edge Services',
#   'name': 'Email',
#   'short_description': 'Oracle Cloud Infrastructure Email Delivery is an SMTP-based email sending service that provides a fast and reliable managed solution for sending high-volume emails that need to reach your recipients’ inbox.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/edge/email-delivery/features',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/EdgeServices.png'},
#  {'category_id': 'ravello',
#   'category_name': 'Ravello Service',
#   'name': 'Ravello Service',
#   'short_description': 'Oracle Cloud Infrastructure Ravello Service seamlessly deploys existing VMware- or KVM- based data center workloads on Oracle Cloud Infrastructure, AWS, or GCP as is, without any modification to the VMs, network, or storage.',
#   'long_description': 'Seamlessly deploy your existing VMware or KVM based datacenter workloads on Oracle Cloud Infrastructure, AWS, or GCP as-is, without any modification to the VMs, network, or storage.',
#   'link': 'https://cloud.oracle.com/en_US/ravello',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/Ravello_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle API Platform Cloud Service',
#   'short_description': 'Manage, monitor, and secure the entire API lifecycle.',
#   'long_description': 'Complete API Lifecycle Management solution that supports agile API development and makes it easy to keep an eye on KPIs. True hybrid API development on any cloud and on premises that is modern and adaptable, employing the most up-to-date security protocols.',
#   'link': 'https://cloud.oracle.com/api-platform',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/APIManager_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Blockchain Cloud Service',
#   'short_description': 'Securely and reliably extend business processes and accelerate B2B transactions.',
#   'long_description': 'A comprehensive distributed ledger cloud platform to provision blockchain networks, join other organizations, and deploy & run smart contracts to update and query the ledger. Reliably share data and conduct trusted transactions with suppliers, banks, and other trade partners through integration with existing or new cloud-based or on-premises applications.',
#   'link': 'https://cloud.oracle.com/blockchain',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/Blockchain_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Digital Assistant',
#   'short_description': 'Quickly build digital assistants that can offer multiple AI-powered skills from multiple back-end systems such as ERP, HCM, and CX.',
#   'long_description': 'Oracle Digital Assistant provides the platform and tools to easily build AI-powered assistants that connect to your backend applications. A digital assistant uses artificial intelligence for natural language processing and understanding, to automate engagements with conversational interfaces that respond instantly, improve user satisfaction, and increase business efficiencies.',
#   'link': 'https://cloud.oracle.com/digital-assistant',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/da_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Mobile Cloud',
#   'short_description': 'Build, deploy, and manage mobile apps that readily connect to any back-end system.',
#   'long_description': 'Quickly build, deploy, and manage mobile apps that connect to Oracle ERP, HCM, CX or any third-party system, on-premise or in the cloud.',
#   'link': 'https://cloud.oracle.com/mobile',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/mobile_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Application Container Cloud Service',
#   'short_description': 'Develop cloud-native, 12-factor applications on a modern polyglot platform.',
#   'long_description': 'Develop cloud native, 12-factor applications on a modern polyglot platform with Java EE, Java SE, Node.js, PHP, Python, Ruby, GO and .NET',
#   'link': 'https://cloud.oracle.com/opc/application-container-cloud',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/applicationcontainer_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Cloud Infrastructure Registry',
#   'short_description': 'Securely store and share Docker container images.',
#   'long_description': 'A highly available private container registry service for storing and sharing container images within the same regions as the deployments.',
#   'link': 'https://cloud.oracle.com/containers/registry',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/OBMC_Container_white-144x144.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Container Engine for Kubernetes',
#   'short_description': 'Take advantage of a fully managed, enterprise-grade Kubernetes container orchestration service.',
#   'long_description': 'A developer friendly, container-native, and enterprise-ready managed Kubernetes service for running highly available clusters with the control, security, and predictable performance of Oracle’s Cloud Infrastructure.',
#   'link': 'https://cloud.oracle.com/containers/kubernetes-engine',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/OBMC_Container_white-144x144.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Container Pipelines',
#   'short_description': 'Speed software development with a continuous integration and delivery (CI/CD) pipeline.',
#   'long_description': 'Oracle Container Pipelines is a CI/CD developer automation platform designed for Microservices and Container Architecture.',
#   'link': 'https://cloud.oracle.com/containers/pipelines',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/wercker-container-pipelines-logo.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Database Cloud Service',
#   'short_description': 'Support any size workload, from DevTest to large-scale production.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Developer Cloud Service',
#   'short_description': 'Get a hosted team development and delivery platform.',
#   'long_description': 'Hosted team development and delivery platform including issue tracking, code versioning, wiki, agile-development tools, continuous integration and delivery automation.',
#   'link': 'https://cloud.oracle.com/developer-service',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/developer_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Java Cloud Service',
#   'short_description': 'Gain easy, rapid, and agile deployment of any Java application.',
#   'long_description': 'Easy, rapid and agile deployment of any Java application. Experience full control and flexibility of your application in public cloud.',
#   'link': 'https://cloud.oracle.com/java',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/Java_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Messaging Cloud Service',
#   'short_description': 'Connect any internet-based apps and devices in the cloud and on premises.',
#   'long_description': 'The Oracle Messaging Cloud Service is a communication backbone delivered as a cloud service that connects any internet-based applications and devices on cloud and on-premise in a flexible, reliable and secure way, ideal for an event-driven service oriented architecture (SOA).',
#   'link': 'https://cloud.oracle.com/messaging',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/messaging_w_72.png'},
#  {'category_id': 'business-analytics',
#   'category_name': 'Business Analytics',
#   'name': 'Oracle Analytics Cloud',
#   'short_description': 'Power data-driven insights and decisions with a single, enterprise-class analytics platform.',
#   'long_description': 'Simplify how you analyze and act on information so you can scale insights across your entire organization.',
#   'link': 'https://cloud.oracle.com/en_US/oac',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/DataAnalyzer_w_72%402x.png'},
#  {'category_id': 'cloud-at-customer',
#   'category_name': 'Cloud at Customer',
#   'name': 'Oracle Big Data Cloud at Customer',
#   'short_description': 'Oracle Big Data Cloud at Customer delivers the complete value of Oracle Big Data Cloud Service to customers who require their big data platform to be located on premises.',
#   'long_description': 'The power of Hadoop and Spark delivered as a secure, automated, high-performance service, which can be fully integrated with existing enterprise data in Oracle Database and Oracle Applications.',
#   'link': 'https://cloud.oracle.com/bigdata',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/bigdata_w_72.png'},
#  {'category_id': 'cloud-at-customer',
#   'category_name': 'Cloud at Customer',
#   'name': 'Oracle Database Exadata Cloud at Customer',
#   'short_description': 'Oracle Database Exadata Cloud at Customer is designed for customers who require their database on premises.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/en_US/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'content-and-experience-management',
#   'category_name': 'Content and Experience Management',
#   'name': 'Oracle Content and Experience Cloud Service',
#   'short_description': 'Drive omnichannel content management and accelerate experience delivery.',
#   'long_description': 'Oracle Content and Experience is a cloud-based content hub to drive omni-channel content management and accelerate experience delivery.',
#   'link': 'https://cloud.oracle.com/en_US/content',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/CECS_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Data Integration',
#   'name': 'Oracle Data Integration Platform Cloud',
#   'short_description': 'Oracle Data Integration Platform Cloud is a next-generation, cloud-based, data integration platform that listens to users, learns from user interaction, and takes corrective actions based on various usage patterns.',
#   'long_description': 'Oracle Data Integration Platform (DIP) helps migrate and extract value from data by bringing together capabilities of a complete Data Integration, Data Quality and Data Governance solution into a single unified cloud based platform. Oracle DIP incorporates machine learning and artificial intelligence powered features including automated data migration and data warehouse building, as well as machine assisted data profiling and governance, allowing customers to service all their data integration needs in one cohesive platform, so that all users can now transition and collaborate across these capabilities and projects seamlessly.',
#   'link': 'https://cloud.oracle.com/en_US/data-integration-platform',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/Data-Integration_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Data Integration',
#   'name': 'Oracle Internet of Things Cloud Service',
#   'short_description': 'Connect, analyze, and integrate device data into your business processes and apps.',
#   'long_description': 'Extend your supply chain, enterprise resource planning, and customer experience applications to the physical world, driving automation powered by intelligent predictive algorithms and digital twins.',
#   'link': 'https://cloud.oracle.com/iot',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/opcServiceIOTBannerIcon.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Big Data Cloud',
#   'short_description': 'Gain the power of Hadoop and Spark in a secure, automated, high-performance service.',
#   'long_description': 'The power of Hadoop and Spark delivered as a secure, automated, high-performance service, which can be fully integrated with existing enterprise data in Oracle Database and Oracle Applications.',
#   'link': 'https://cloud.oracle.com/bigdata',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/bigdata_w_72.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Big Data Cloud Service',
#   'short_description': 'Gain the power of Hadoop and Spark in a secure, automated, high-performance service.',
#   'long_description': 'The power of Hadoop and Spark delivered as a secure, automated, high-performance service, which can be fully integrated with existing enterprise data in Oracle Database and Oracle Applications.',
#   'link': 'https://cloud.oracle.com/bigdata',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/bigdata_w_72.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Autonomous Data Warehouse Cloud Service',
#   'short_description': 'Take advantage of a fully managed, autonomous, high-performance, elastic cloud service for data warehousing.',
#   'long_description': 'Oracle Autonomous Data Warehouse provides an easy-to-use, fully autonomous database that scales elastically, delivers fast query performance and requires no database administration.',
#   'link': 'https://cloud.oracle.com/en_US/datawarehouse',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/data-warehouse-cloud-service_w_72.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Database Backup Service',
#   'short_description': 'Store and access backup data with reliable, scalable, object storage.',
#   'long_description': 'A reliable and scalable object storage solution for storing and accessing your ever-growing Oracle Database backup data.',
#   'link': 'https://cloud.oracle.com/database_backup',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/databasebackup_w_72.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Database Cloud Service',
#   'short_description': 'Support any size workload, from DevTest to large-scale production.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Database Cloud Service—Bare Metal',
#   'short_description': 'Get consistent high performance with no virtualization overhead.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Database Exadata Cloud at Customer',
#   'short_description': 'Get the power of Oracle Database Cloud on premises.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/en_US/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Database Exadata Cloud Service',
#   'short_description': 'Experience all the power of Oracle Exadata for Oracle Cloud.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Database Exadata Express Cloud Service',
#   'short_description': 'Expedite modern application development. Great for small- to medium-size data volumes.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Event Hub Cloud Service',
#   'short_description': 'Gain the power of Kafka as a managed, streaming-data platform integrated with Oracle Cloud.',
#   'long_description': 'Oracle Event Hub Cloud Service delivers the power of Kafka as a managed streaming data platform integrated into the Oracle Cloud ecosystem. Create Topics and start streaming or manage and deploy your own Dedicated Kafka Cluster with Elastic Scalability.',
#   'link': 'https://cloud.oracle.com/event-hub',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/kafka_w_72.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Exadata Cloud Service—Bare Metal',
#   'short_description': 'Get the highest performance, availability, and reliability on Oracle Cloud Infrastructure.',
#   'long_description': '',
#   'link': 'https://cloud.oracle.com/en_US/infrastructure/database/features/exadata',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle MySQL Cloud Service',
#   'short_description': 'Utilize secure, cost-effective, enterprise-grade MySQL.',
#   'long_description': 'The world’s most popular open source database powered by the Oracle Cloud, delivering a secure, cost-effective and enterprise-grade MySQL database service for your modern applications.',
#   'link': 'https://cloud.oracle.com/mysql',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/MySQL_w_72.png'},
#  {'category_id': 'data-management',
#   'category_name': 'Data Management',
#   'name': 'Oracle Autonomous NoSQL Database Cloud Service',
#   'short_description': 'Get on-demand throughput and storage-based provisioning.',
#   'long_description': 'A NoSQL database service with on-demand throughput and storage based provisioning that supports JSON, Table and Key-Value datatypes, all with flexible transaction guarantees.',
#   'link': 'https://cloud.oracle.com/nosqldatabase',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/NoSQL_w_72.png'},
#  {'category_id': 'enterprise-integration',
#   'category_name': 'Enterprise Integration',
#   'name': 'Oracle API Platform Cloud Service ',
#   'short_description': 'Manage, monitor, and secure the entire API lifecycle.',
#   'long_description': 'Complete API Lifecycle Management solution that supports agile API development and makes it easy to keep an eye on KPIs. True hybrid API development on any cloud and on premises that is modern and adaptable, employing the most up-to-date security protocols.',
#   'link': 'https://cloud.oracle.com/en_US/api-platform',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/APIManager_w_72.png'},
#  {'category_id': 'enterprise-integration',
#   'category_name': 'Enterprise Integration',
#   'name': 'Oracle Integration Cloud Service',
#   'short_description': 'Easily connect Oracle and non-Oracle applications.',
#   'long_description': 'Oracle Integration eliminates barriers between business applications through a combination of machine learning, embedded best-practice guidance, prebuilt integration, and process automation. Oracle Integration is unique in the market by leveraging Oracle application expertise to build an extensive library of adapters to Oracle and 3rd party SaaS and on-premises applications to enable you to deliver new business services faster.',
#   'link': 'https://cloud.oracle.com/en_US/integration',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/Integration-cloud_w_72%402x.png'},
#  {'category_id': 'enterprise-integration',
#   'category_name': 'Enterprise Integration',
#   'name': 'Oracle SOA Cloud Service',
#   'short_description': 'Gain powerful application integration and orchestration.',
#   'long_description': 'SOA Cloud Service provides an integration platform as a service (iPaaS) so that you can quickly provision your new platform, start developing and deploying your APIs and integration projects and provide real-time analytics as you transition to Digital Business.',
#   'link': 'https://cloud.oracle.com/en_US/soa',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/SOA_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'name': 'Oracle CASB Cloud Service',
#   'short_description': 'Gain visibility into your entire cloud stack with a security automation tool.',
#   'long_description': 'The Oracle CASB Cloud Service is the only Cloud Access Security Broker (CASB) that gives you both visibility into your entire cloud stack and the security automation tool your IT team needs.',
#   'link': 'https://cloud.oracle.com/en_US/casb',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/PalerraLORIC_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'name': 'Oracle Configuration and Compliance Cloud Service',
#   'short_description': 'Assess, score, and remediate violations using industry-standard benchmarks and custom rules.',
#   'long_description': "Oracle Configuration and Compliance Service enables the IT and Business Compliance function to assess, score and remediate violations using industry standard benchmarks in addition to your own custom rules. The Oracle Configuration and Compliance Service can assess both on premise and cloud infrastructure. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/compliance',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/ComplianceCloudService_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'name': 'Oracle Identity Cloud Service',
#   'short_description': 'Secure, on-demand identity for modern applications.',
#   'long_description': 'The next generation comprehensive security and identity platform that is cloud-native and designed to be an integral part of the enterprise security fabric, providing modern identity for modern applications',
#   'link': 'https://cloud.oracle.com/en_US/identity',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/IdentityMgmt_w_72.png'},
#  {'category_id': 'security',
#   'category_name': 'Security',
#   'name': 'Oracle Security Monitoring and Analytics Cloud Service',
#   'short_description': 'Rapidly detect, investigate, and remediate threats, on premises and in the cloud.',
#   'long_description': "Oracle Security Monitoring and Analytics (SMA) Cloud Service enables rapid detection, investigation and remediation of the broadest range of security threats across on-premises and cloud IT assets. Security Monitoring and Analytics provides integrated SIEM and UEBA capabilities built on machine learning, user session awareness, and up-to-date threat intelligence context. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/en_US/security-analytics',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/SecurityMonitoringandAnalytics_w_72.png'},
#  {'category_id': 'systems-management',
#   'category_name': 'Systems Management',
#   'name': 'Oracle Application Performance Monitoring Cloud Service',
#   'short_description': 'Get all your end-user and app performance information in a secure, unified, big data platform.',
#   'long_description': "Oracle Application Performance Monitoring Cloud Service provides development and operations teams with the information that they need to find and fix application issues fast. All your end-user and application performance information (with associated application logs) are brought together into Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/application-performance-monitoring',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/AppPerfMonitoring_w_72.png'},
#  {'category_id': 'systems-management',
#   'category_name': 'Systems Management',
#   'name': 'Oracle Configuration and Compliance Cloud Service',
#   'short_description': 'Assess, score, and remediate violations using industry-standard benchmarks and custom rules.',
#   'long_description': "Oracle Configuration and Compliance Service enables the IT and Business Compliance function to assess, score and remediate violations using industry standard benchmarks in addition to your own custom rules. The Oracle Configuration and Compliance Service can assess both on premise and cloud infrastructure. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/compliance',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/ComplianceCloudService_w_72.png'},
#  {'category_id': 'systems-management',
#   'category_name': 'Systems Management',
#   'name': 'Oracle Infrastructure Monitoring Cloud Service',
#   'short_description': 'Monitor your entire IT infrastructure—on premises or in the cloud—from one platform.',
#   'long_description': "Oracle Infrastructure Monitoring Cloud Service monitors the status and health of your entire IT infrastructure - on-premises or on the cloud -- from a single platform. Proactive monitoring across tiers enables administrators to be alerted on issues, troubleshoot and resolve these before they impact end users. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/infrastructure-monitoring',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/CloudInfrastructureMonitoringService_w_72.png'},
#  {'category_id': 'systems-management',
#   'category_name': 'Systems Management',
#   'name': 'Oracle IT Analytics Cloud Service',
#   'short_description': 'Gain insight into the performance, availability, and capacity of apps and infrastructure.',
#   'long_description': "Oracle IT Analytics Cloud Service provides 360-degree insight into the performance, availability, and capacity of applications and infrastructure investments, enabling line-of-business and IT executives, analysts, and administrators to make critical decisions about their IT estate. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/it-analytics',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/ItAnalytics_w_72.png'},
#  {'category_id': 'systems-management',
#   'category_name': 'Systems Management',
#   'name': 'Oracle Log Analytics Cloud Service',
#   'short_description': 'Search, explore, and correlate data to tackle problems faster and make better decisions.',
#   'long_description': "Oracle Log Analytics Cloud Service monitors, aggregates, indexes, and analyzes all log data from your applications and infrastructure – enabling users to search, explore, and correlate this data to troubleshoot problems faster, derive operational insight, and make better decisions. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/log-analytics',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/LogAnalytics_w_72.png'},
#  {'category_id': 'systems-management',
#   'category_name': 'Systems Management',
#   'name': 'Oracle Orchestration Cloud Service',
#   'short_description': 'Schedule, execute, and report on tasks at cloud scale.',
#   'long_description': "Oracle Orchestration Cloud Service enables automation of tasks executed at hyper-scale by calling REST endpoints, scripts, or 3rd party automation frameworks. Oracle Orchestration Cloud Service seamlessly executes these tasks on-premises, in the cloud, or across hybrid cloud environments. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/orchestration',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/OrchestrationCloudService_w_72.png'},
#  {'category_id': 'systems-management',
#   'category_name': 'Systems Management',
#   'name': 'Oracle Security Monitoring and Analytics Cloud Service',
#   'short_description': 'Rapidly detect, investigate, and remediate threats, on premises and in the cloud.',
#   'long_description': "Oracle Security Monitoring and Analytics (SMA) Cloud Service enables rapid detection, investigation and remediation of the broadest range of security threats across on-premises and cloud IT assets. Security Monitoring and Analytics provides integrated SIEM and UEBA capabilities built on machine learning, user session awareness, and up-to-date threat intelligence context. This service is built on Oracle Management Cloud's secure, unified big data platform.",
#   'link': 'https://cloud.oracle.com/en_US/security-analytics',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/SecurityMonitoringandAnalytics_w_72.png'}]

# %%
services
# Out:
# [{'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle API Platform Cloud Service',
#   'short_description': 'Manage, monitor, and secure the entire API lifecycle.',
#   'long_description': 'Complete API Lifecycle Management solution that supports agile API development and makes it easy to keep an eye on KPIs. True hybrid API development on any cloud and on premises that is modern and adaptable, employing the most up-to-date security protocols.',
#   'link': 'https://cloud.oracle.com/api-platform',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/APIManager_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Blockchain Cloud Service',
#   'short_description': 'Securely and reliably extend business processes and accelerate B2B transactions.',
#   'long_description': 'A comprehensive distributed ledger cloud platform to provision blockchain networks, join other organizations, and deploy & run smart contracts to update and query the ledger. Reliably share data and conduct trusted transactions with suppliers, banks, and other trade partners through integration with existing or new cloud-based or on-premises applications.',
#   'link': 'https://cloud.oracle.com/blockchain',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/Blockchain_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Digital Assistant',
#   'short_description': 'Quickly build digital assistants that can offer multiple AI-powered skills from multiple back-end systems such as ERP, HCM, and CX.',
#   'long_description': 'Oracle Digital Assistant provides the platform and tools to easily build AI-powered assistants that connect to your backend applications. A digital assistant uses artificial intelligence for natural language processing and understanding, to automate engagements with conversational interfaces that respond instantly, improve user satisfaction, and increase business efficiencies.',
#   'link': 'https://cloud.oracle.com/digital-assistant',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/da_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Mobile Cloud',
#   'short_description': 'Build, deploy, and manage mobile apps that readily connect to any back-end system.',
#   'long_description': 'Quickly build, deploy, and manage mobile apps that connect to Oracle ERP, HCM, CX or any third-party system, on-premise or in the cloud.',
#   'link': 'https://cloud.oracle.com/mobile',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/mobile_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Application Container Cloud Service',
#   'short_description': 'Develop cloud-native, 12-factor applications on a modern polyglot platform.',
#   'long_description': 'Develop cloud native, 12-factor applications on a modern polyglot platform with Java EE, Java SE, Node.js, PHP, Python, Ruby, GO and .NET',
#   'link': 'https://cloud.oracle.com/opc/application-container-cloud',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/applicationcontainer_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Cloud Infrastructure Registry',
#   'short_description': 'Securely store and share Docker container images.',
#   'long_description': 'A highly available private container registry service for storing and sharing container images within the same regions as the deployments.',
#   'link': 'https://cloud.oracle.com/containers/registry',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/OBMC_Container_white-144x144.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Container Engine for Kubernetes',
#   'short_description': 'Take advantage of a fully managed, enterprise-grade Kubernetes container orchestration service.',
#   'long_description': 'A developer friendly, container-native, and enterprise-ready managed Kubernetes service for running highly available clusters with the control, security, and predictable performance of Oracle’s Cloud Infrastructure.',
#   'link': 'https://cloud.oracle.com/containers/kubernetes-engine',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/OBMC_Container_white-144x144.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Container Pipelines',
#   'short_description': 'Speed software development with a continuous integration and delivery (CI/CD) pipeline.',
#   'long_description': 'Oracle Container Pipelines is a CI/CD developer automation platform designed for Microservices and Container Architecture.',
#   'link': 'https://cloud.oracle.com/containers/pipelines',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/wercker-container-pipelines-logo.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Database Cloud Service',
#   'short_description': 'Support any size workload, from DevTest to large-scale production.',
#   'long_description': 'Oracle Database on Oracle Cloud Infrastructure is available in flexible configurations to run all of your database workloads, large or small, with the performance and power of Oracle Engineered Systems.',
#   'link': 'https://cloud.oracle.com/database',
#   'icon': 'https://cloud.oracle.com/opc/iaas/images/BMCSDatabase_w_72%402x.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Developer Cloud Service',
#   'short_description': 'Get a hosted team development and delivery platform.',
#   'long_description': 'Hosted team development and delivery platform including issue tracking, code versioning, wiki, agile-development tools, continuous integration and delivery automation.',
#   'link': 'https://cloud.oracle.com/developer-service',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/developer_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Java Cloud Service',
#   'short_description': 'Gain easy, rapid, and agile deployment of any Java application.',
#   'long_description': 'Easy, rapid and agile deployment of any Java application. Experience full control and flexibility of your application in public cloud.',
#   'link': 'https://cloud.oracle.com/java',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/Java_w_72.png'},
#  {'category_id': 'application-development',
#   'category_name': 'Application Development',
#   'name': 'Oracle Messaging Cloud Service',
#   'short_description': 'Connect any internet-based apps and devices in the cloud and on premises.',
#   'long_description': 'The Oracle Messaging Cloud Service is a communication backbone delivered as a cloud service that connects any internet-based applications and devices on cloud and on-premise in a flexible, reliable and secure way, ideal for an event-driven service oriented architecture (SOA).',
#   'link': 'https://cloud.oracle.com/messaging',
#   'icon': 'https://cloud.oracle.com/opc/paas/images/messaging_w_72.png'}]
